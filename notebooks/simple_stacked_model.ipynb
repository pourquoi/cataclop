# %%
import time

import pandas as pd
import numpy as np

import matplotlib
# %matplotlib inline

from cataclop.ml.pipeline import factories

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
MAX_HISTORY = 6
NAN_FLAG = 10000.

# %%
d = factories.Dataset.factory('default')
d.load(force=True)

# %%
pd.concat([pd.DataFrame(d.players.describe()).T, d.players.dtypes], axis=1, sort=True)
# Out:
#                           count          mean           std      min  \
# age                    138408.0  5.023770e+00  2.013027e+00      1.0
# category                    NaN           NaN           NaN      NaN
# code                        NaN           NaN           NaN      NaN
# condition_age               NaN           NaN           NaN      NaN
# condition_sex               NaN           NaN           NaN      NaN
# country                     NaN           NaN           NaN      NaN
# date                        NaN           NaN           NaN      NaN
# declared_player_count  138408.0  1.233263e+01  3.128411e+00      3.0
# distance               138408.0  1.928350e+03  4.998067e+02    800.0
# earnings               138408.0  5.909599e+06  1.784700e+07      0.0
# final_odds             134956.0  2.474055e+01  2.819622e+01      1.1
# final_odds_ref         130259.0  2.132369e+01  2.985993e+01      1.1
# handicap_distance       44534.0  2.262857e+03  2.982299e+02   1600.0
# handicap_weight         65228.0  2.893972e+01  9.979645e+00      2.0
# herder_id               90643.0  2.028646e+03  2.069105e+03      1.0
# hippodrome_id          138408.0  6.918459e+01  6.306184e+01      1.0
# hist_1_pos             138408.0  3.252348e+00  2.876777e+00      0.0
# hist_2_pos             138408.0  3.087871e+00  2.868047e+00      0.0
# hist_3_pos             138408.0  2.941817e+00  2.864269e+00      0.0
# hist_4_pos             138408.0  2.769175e+00  2.853434e+00      0.0
# hist_5_pos             138408.0  2.181435e+00  2.766616e+00      0.0
# hist_6_pos             138408.0  1.808443e+00  2.651253e+00      0.0
# horse_id               138408.0  1.957640e+04  1.533631e+04      1.0
# imported_at_hippo           NaN           NaN           NaN      NaN
# imported_at_player          NaN           NaN           NaN      NaN
# imported_at_race            NaN           NaN           NaN      NaN
# imported_at_session         NaN           NaN           NaN      NaN
# is_first_timer              NaN           NaN           NaN      NaN
# is_racing                   NaN           NaN           NaN      NaN
# jockey_id              138408.0  1.623638e+03  1.892748e+03      1.0
# music                       NaN           NaN           NaN      NaN
# name                        NaN           NaN           NaN      NaN
# num                    138408.0  6.633764e+00  3.958557e+00      1.0
# num_bis                 21463.0  1.624517e+00  6.578125e-01      1.0
# num_race               138408.0  4.511625e+00  2.339521e+00      1.0
# num_session            138408.0  3.517932e+00  1.856311e+00      1.0
# owner_id               138407.0  7.521453e+03  7.403748e+03      1.0
# placed_2_count         138408.0  2.136264e+00  3.007273e+00      0.0
# placed_3_count         138408.0  2.021899e+00  2.817025e+00      0.0
# placed_count           138408.0  8.445993e+00  1.106858e+01      0.0
# placed_dividend        138408.0  7.639898e+01  1.919143e+02      0.0
# placed_earnings        138408.0  2.630591e+06  9.488772e+06      0.0
# position               115471.0  5.942912e+00  3.566114e+00      1.0
# post_position          138408.0  6.645721e+00  3.969611e+00      1.0
# prev_year_earnings     138408.0  1.689348e+06  7.849281e+06      0.0
# prize                  138408.0  4.203931e+04  2.804421e+05    740.0
# race_count             138408.0  2.023145e+01  2.529483e+01      0.0
# race_id                138408.0  1.032947e+04  5.900532e+03      1.0
# session_id             138408.0  1.657520e+03  9.275947e+02      1.0
# start_at                    NaN           NaN           NaN      NaN
# sub_category                NaN           NaN           NaN      NaN
# time                    30581.0  1.740355e+05  2.587250e+04  27100.0
# trainer_id             138408.0  1.793662e+03  1.916018e+03      1.0
# victory_count          138408.0  2.164925e+00  3.083566e+00      0.0
# victory_earnings       138408.0  5.909599e+06  1.784700e+07      0.0
# winner_dividend        138408.0  7.242356e+01  3.974950e+02      0.0
# year_earnings          138408.0  8.000577e+05  5.626360e+06      0.0
#
#                              25%        50%        75%           max  \
# age                         3.00        5.0        6.0  1.600000e+01
# category                     NaN        NaN        NaN           NaN
# code                         NaN        NaN        NaN           NaN
# condition_age                NaN        NaN        NaN           NaN
# condition_sex                NaN        NaN        NaN           NaN
# country                      NaN        NaN        NaN           NaN
# date                         NaN        NaN        NaN           NaN
# declared_player_count      10.00       12.0       15.0  2.400000e+01
# distance                 1600.00     2000.0     2300.0  6.856000e+03
# earnings               490000.00  2027500.0  6045000.0  1.471275e+09
# final_odds                  7.00       14.2       31.2  8.147000e+02
# final_odds_ref              7.70       13.8       24.8  9.990000e+02
# handicap_distance        2100.00     2150.0     2550.0  3.150000e+03
# handicap_weight            23.00       29.0       35.0  7.100000e+01
# herder_id                 399.00     1209.0     3074.0  9.210000e+03
# hippodrome_id              21.00       49.0      105.0  2.740000e+02
# hist_1_pos                  0.00        3.0        6.0  9.000000e+00
# hist_2_pos                  0.00        3.0        5.0  9.000000e+00
# hist_3_pos                  0.00        2.0        5.0  9.000000e+00
# hist_4_pos                  0.00        2.0        5.0  9.000000e+00
# hist_5_pos                  0.00        1.0        4.0  9.000000e+00
# hist_6_pos                  0.00        0.0        3.0  9.000000e+00
# horse_id                 6544.75    15363.0    30188.0  5.677000e+04
# imported_at_hippo            NaN        NaN        NaN           NaN
# imported_at_player           NaN        NaN        NaN           NaN
# imported_at_race             NaN        NaN        NaN           NaN
# imported_at_session          NaN        NaN        NaN           NaN
# is_first_timer               NaN        NaN        NaN           NaN
# is_racing                    NaN        NaN        NaN           NaN
# jockey_id                 139.00      941.0     2458.0  8.937000e+03
# music                        NaN        NaN        NaN           NaN
# name                         NaN        NaN        NaN           NaN
# num                         3.00        6.0        9.0  2.400000e+01
# num_bis                     1.00        2.0        2.0  4.000000e+00
# num_race                    3.00        4.0        6.0  1.200000e+01
# num_session                 2.00        3.0        5.0  1.200000e+01
# owner_id                 1626.00     4776.0    11394.0  2.933700e+04
# placed_2_count              0.00        1.0        3.0  4.200000e+01
# placed_3_count              0.00        1.0        3.0  4.600000e+01
# placed_count                1.00        4.0       12.0  1.310000e+02
# placed_dividend             0.00        0.0        0.0  4.610000e+03
# placed_earnings         25000.00   780000.0  2739000.0  1.061760e+09
# position                    3.00        6.0        8.0  2.300000e+01
# post_position               3.00        6.0        9.0  2.400000e+01
# prev_year_earnings          0.00   395335.0  1722000.0  7.835376e+08
# prize                    6406.00    17000.0    24000.0  1.386022e+07
# race_count                  2.00       11.0       29.0  3.940000e+02
# race_id                  5224.00    10560.0    15248.0  2.055700e+04
# session_id                848.00     1737.0     2416.0  3.250000e+03
# start_at                     NaN        NaN        NaN           NaN
# sub_category                 NaN        NaN        NaN           NaN
# time                   157930.00   167410.0   196000.0  3.534300e+05
# trainer_id                380.00     1136.0     2678.0  9.032000e+03
# victory_count               0.00        1.0        3.0  5.300000e+01
# victory_earnings       490000.00  2027500.0  6045000.0  1.471275e+09
# winner_dividend             0.00        0.0        0.0  1.844000e+04
# year_earnings               0.00    58000.0   665000.0  1.119697e+09
#
#                                     0
# age                             int64
# category                     category
# code                           object
# condition_age                category
# condition_sex                category
# country                      category
# date                           object
# declared_player_count           int64
# distance                        int64
# earnings                        int64
# final_odds                    float64
# final_odds_ref                float64
# handicap_distance             float64
# handicap_weight               float64
# herder_id                     float64
# hippodrome_id                   int64
# hist_1_pos                    float64
# hist_2_pos                    float64
# hist_3_pos                    float64
# hist_4_pos                    float64
# hist_5_pos                    float64
# hist_6_pos                    float64
# horse_id                        int64
# imported_at_hippo      datetime64[ns]
# imported_at_player     datetime64[ns]
# imported_at_race       datetime64[ns]
# imported_at_session    datetime64[ns]
# is_first_timer                   bool
# is_racing                        bool
# jockey_id                       int64
# music                          object
# name                           object
# num                             int64
# num_bis                       float64
# num_race                        int64
# num_session                     int64
# owner_id                      float64
# placed_2_count                  int64
# placed_3_count                  int64
# placed_count                    int64
# placed_dividend               float64
# placed_earnings                 int64
# position                      float64
# post_position                   int64
# prev_year_earnings              int64
# prize                           int64
# race_count                      int64
# race_id                         int64
# session_id                      int64
# start_at               datetime64[ns]
# sub_category                 category
# time                          float64
# trainer_id                      int64
# victory_count                   int64
# victory_earnings                int64
# winner_dividend               float64
# year_earnings                   int64

# %%
df = d.players.groupby('race_id').filter(lambda race: race['race_count'].max() > 0)

races = df.groupby('race_id')

agg_features = ['race_count', 
                'victory_count', 
                'placed_2_count', 
                'placed_3_count',
                'victory_earnings',
                'prev_year_earnings',
                'handicap_distance',
                'handicap_weight',
                'final_odds_ref'
               ] + ['hist_{}_pos'.format(i+1) for i in range(MAX_HISTORY)]

stats = races[agg_features].agg([np.mean, np.std])
stats.columns = ['_'.join(col) for col in stats.columns.values]

df = df.join(stats, how='left', on='race_id')

for f in agg_features:
    df['{}_r'.format(f)] = (df[f] - df['{}_mean'.format(f)]) / df['{}_std'.format(f)]
    
agg_features = ['{}_r'.format(f) for f in agg_features if f != 'final_odds_ref'] + ['{}_std'.format(f) for f in agg_features] + ['{}_mean'.format(f) for f in agg_features]

df[agg_features] = df[agg_features].replace([np.inf, -np.inf], np.nan)
df[agg_features] = df[agg_features].fillna(NAN_FLAG)

# %%
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler

start = time.time()

odds = np.ones([len(df), 20]) * NAN_FLAG
idx = []

races = df.groupby('race_id')

j = 0
for (id, race) in races:
    jj = len(race.index)
    odds_sorted = np.array(sorted(race[race['final_odds_ref']>1.]['final_odds_ref'].values))
    
    
    
    odds[j:j+jj, 0:len(odds_sorted)] = odds_sorted[:20]
    
    idx = idx + list(race.index)
    
    j = j + jj
    
#scaler = StandardScaler()
#odds = scaler.fit_transform(odds)
    
odds_df = pd.DataFrame(odds, columns=['odds_{:d}'.format(i) for i in range(20)], index=idx)
df = pd.concat([df,odds_df], axis=1)

end = time.time()
print(end - start)
# Out:
# 33.607139110565186

# %%
print(df['start_at'].min(), df['start_at'].max())
# Out:
# 2017-01-01 12:40:00 2018-06-22 21:24:00

# %%
df['speed'] = (df['distance'] / df['time']).fillna(NAN_FLAG)
df['final_odds_ref_inv'] = (1. / df['final_odds_ref']).fillna(NAN_FLAG)

df = df.groupby('race_id').filter(lambda r: r['position'].min() == 1)
df = df.groupby('race_id').filter(lambda r: r['final_odds_ref'].min() > 0)
df = df.sort_index()
df_orig = df.copy()

# %%
#df_test = df_orig[(df_orig['start_at'] > '2018-06-01') & (df_orig['category']=='PLAT')].copy()
df_test = df_orig[(df_orig['start_at'] > '2018-06-07')].copy()
df = df_orig[(df_orig['start_at'] <= '2018-06-06')].copy()

df_test = df_test.sort_index()
df = df.sort_index()

# %%
pd.concat([pd.DataFrame(df.describe()).T, df.dtypes], axis=1, sort=True)

dff = df.reset_index()
pd.concat([pd.DataFrame(dff.describe()).T, dff.dtypes], axis=1, sort=True)
# Out:
#                             count          mean           std           min  \
# age                      106780.0  5.036346e+00  2.025373e+00  1.000000e+00
# category                      NaN           NaN           NaN           NaN
# code                          NaN           NaN           NaN           NaN
# condition_age                 NaN           NaN           NaN           NaN
# condition_sex                 NaN           NaN           NaN           NaN
# country                       NaN           NaN           NaN           NaN
# date                          NaN           NaN           NaN           NaN
# declared_player_count    106780.0  1.243496e+01  3.162771e+00  3.000000e+00
# distance                 106780.0  1.926085e+03  5.155121e+02  8.000000e+02
# earnings                 106780.0  6.188416e+06  1.809054e+07  0.000000e+00
# final_odds               106639.0  2.495201e+01  2.844481e+01  1.100000e+00
# final_odds_ref           106262.0  2.072050e+01  2.591540e+01  1.100000e+00
# final_odds_ref_inv       106780.0  4.861750e+01  6.948025e+02  1.001001e-03
# final_odds_ref_mean      106780.0  2.071086e+01  1.408424e+01  1.100000e+00
# final_odds_ref_r         106260.0          -inf           NaN          -inf
# final_odds_ref_std       106780.0  1.847945e+01  1.268774e+02  0.000000e+00
# handicap_distance         29213.0  2.324546e+03  2.926124e+02  1.600000e+03
# handicap_distance_mean   106780.0  7.900140e+03  3.425128e+03  1.600000e+03
# handicap_distance_r      106780.0  9.999251e+03  8.655373e+01 -2.474874e+00
# handicap_distance_std    106780.0  7.264189e+03  4.457985e+03  0.000000e+00
# handicap_weight           55452.0  2.894617e+01  1.006308e+01  2.000000e+00
# handicap_weight_mean     106780.0  3.833005e+03  4.843285e+03  4.222222e+00
# handicap_weight_r        106780.0  4.838453e+03  4.997413e+03 -3.409262e+00
# handicap_weight_std      106780.0  4.034505e+03  4.904159e+03  0.000000e+00
# herder_id                 74652.0  2.076642e+03  2.062180e+03  1.000000e+00
# hippodrome_id            106780.0  6.833899e+01  6.321451e+01  1.000000e+00
# hist_1_pos               106780.0  3.344034e+00  2.896662e+00  0.000000e+00
# hist_1_pos_mean          106780.0  3.344034e+00  1.013055e+00  0.000000e+00
# hist_1_pos_r             106780.0  6.836486e+00  2.613803e+02 -2.729153e+00
# hist_1_pos_std           106780.0  2.782613e+00  5.752226e-01  0.000000e+00
# ...                           ...           ...           ...           ...
# placed_dividend          106780.0  8.001311e+01  1.970439e+02  0.000000e+00
# placed_earnings          106780.0  3.018382e+06  1.044911e+07  0.000000e+00
# position                  98208.0  6.004837e+00  3.603859e+00  1.000000e+00
# post_position            106780.0  6.695083e+00  4.002880e+00  1.000000e+00
# prev_year_earnings       106780.0  1.911908e+06  8.461941e+06  0.000000e+00
# prev_year_earnings_mean  106780.0  1.911908e+06  5.157400e+06  0.000000e+00
# prev_year_earnings_r     106780.0  8.334894e+02  2.764102e+03 -2.902562e+00
# prev_year_earnings_std   106780.0  1.739671e+06  6.877314e+06  0.000000e+00
# prize                    106780.0  4.324727e+04  2.911882e+05  7.400000e+02
# race_count               106780.0  2.287965e+01  2.605999e+01  0.000000e+00
# race_count_mean          106780.0  2.287965e+01  2.034675e+01  6.250000e-02
# race_count_r             106780.0  1.217456e+00  1.103363e+02 -2.967080e+00
# race_count_std           106780.0  1.267162e+01  1.137468e+01  0.000000e+00
# race_id                  106780.0  1.015078e+04  5.611771e+03  1.000000e+00
# session_id               106780.0  1.630946e+03  8.822780e+02  1.000000e+00
# speed                    106780.0  7.913844e+03  4.063205e+03  6.362264e-03
# start_at                      NaN           NaN           NaN           NaN
# sub_category                  NaN           NaN           NaN           NaN
# time                      22276.0  1.780569e+05  2.481296e+04  2.710000e+04
# trainer_id               106780.0  1.648890e+03  1.842937e+03  1.000000e+00
# victory_count            106780.0  2.448708e+00  3.197405e+00  0.000000e+00
# victory_count_mean       106780.0  2.448708e+00  2.313360e+00  0.000000e+00
# victory_count_r          106780.0  1.456827e+03  3.527895e+03 -3.750000e+00
# victory_count_std        106780.0  1.730613e+00  1.536833e+00  0.000000e+00
# victory_earnings         106780.0  6.188416e+06  1.809054e+07  0.000000e+00
# victory_earnings_mean    106780.0  6.188416e+06  1.282137e+07  0.000000e+00
# victory_earnings_r       106780.0  1.807455e+01  4.247604e+02 -3.636153e+00
# victory_earnings_std     106780.0  4.050224e+06  1.283585e+07  0.000000e+00
# winner_dividend          106780.0  7.761940e+01  4.081736e+02  0.000000e+00
# year_earnings            106780.0  8.425136e+05  4.716685e+06  0.000000e+00
#
#                                   25%           50%           75%  \
# age                      3.000000e+00  5.000000e+00  6.000000e+00
# category                          NaN           NaN           NaN
# code                              NaN           NaN           NaN
# condition_age                     NaN           NaN           NaN
# condition_sex                     NaN           NaN           NaN
# country                           NaN           NaN           NaN
# date                              NaN           NaN           NaN
# declared_player_count    1.000000e+01  1.200000e+01  1.500000e+01
# distance                 1.500000e+03  2.000000e+03  2.300000e+03
# earnings                 6.241552e+05  2.365000e+06  6.572000e+06
# final_odds               7.100000e+00  1.410000e+01  3.120000e+01
# final_odds_ref           7.800000e+00  1.370000e+01  2.450000e+01
# final_odds_ref_inv       4.098361e-02  7.299270e-02  1.298701e-01
# final_odds_ref_mean      1.408333e+01  1.802941e+01  2.355000e+01
# final_odds_ref_r        -6.929258e-01 -2.695739e-01  5.059687e-01
# final_odds_ref_std       8.742209e+00  1.311801e+01  2.043825e+01
# handicap_distance        2.100000e+03  2.300000e+03  2.600000e+03
# handicap_distance_mean   2.700000e+03  1.000000e+04  1.000000e+04
# handicap_distance_r      1.000000e+04  1.000000e+04  1.000000e+04
# handicap_distance_std    0.000000e+00  1.000000e+04  1.000000e+04
# handicap_weight          2.300000e+01  2.900000e+01  3.500000e+01
# handicap_weight_mean     2.770000e+01  3.650000e+01  1.000000e+04
# handicap_weight_r        0.000000e+00  1.585694e+00  1.000000e+04
# handicap_weight_std      2.416215e+00  4.025487e+00  1.000000e+04
# herder_id                4.390000e+02  1.361500e+03  3.152000e+03
# hippodrome_id            2.100000e+01  4.800000e+01  1.050000e+02
# hist_1_pos               0.000000e+00  3.000000e+00  6.000000e+00
# hist_1_pos_mean          2.666667e+00  3.307692e+00  4.000000e+00
# hist_1_pos_r            -8.247621e-01 -1.401573e-01  7.845298e-01
# hist_1_pos_std           2.434988e+00  2.844452e+00  3.195980e+00
# ...                               ...           ...           ...
# placed_dividend          0.000000e+00  0.000000e+00  1.100000e+02
# placed_earnings          2.132548e+05  1.079252e+06  3.171050e+06
# position                 3.000000e+00  6.000000e+00  8.000000e+00
# post_position            3.000000e+00  6.000000e+00  1.000000e+01
# prev_year_earnings       0.000000e+00  6.270985e+05  1.980000e+06
# prev_year_earnings_mean  2.550000e+05  9.850625e+05  1.990000e+06
# prev_year_earnings_r    -6.176882e-01 -1.806879e-01  8.945692e-01
# prev_year_earnings_std   3.124584e+05  7.967434e+05  1.378752e+06
# prize                    8.000000e+03  1.800000e+04  2.500000e+04
# race_count               5.000000e+00  1.400000e+01  3.200000e+01
# race_count_mean          6.705882e+00  1.745455e+01  3.350000e+01
# race_count_r            -6.924058e-01 -2.249507e-01  5.825753e-01
# race_count_std           4.033759e+00  9.551863e+00  1.886053e+01
# race_id                  5.383000e+03  1.035900e+04  1.481400e+04
# session_id               8.740000e+02  1.706000e+03  2.354000e+03
# speed                    1.000000e+04  1.000000e+04  1.000000e+04
# start_at                          NaN           NaN           NaN
# sub_category                      NaN           NaN           NaN
# time                     1.600200e+05  1.737250e+05  2.007000e+05
# trainer_id               3.710000e+02  9.550000e+02  2.475000e+03
# victory_count            0.000000e+00  1.000000e+00  4.000000e+00
# victory_count_mean       6.000000e-01  1.916667e+00  3.785714e+00
# victory_count_r         -6.123724e-01  0.000000e+00  1.236865e+00
# victory_count_std        6.304252e-01  1.414214e+00  2.533295e+00
# victory_earnings         6.241552e+05  2.365000e+06  6.572000e+06
# victory_earnings_mean    1.012482e+06  2.840121e+06  7.183944e+06
# victory_earnings_r      -6.820880e-01 -1.801745e-01  6.168384e-01
# victory_earnings_std     5.106131e+05  1.374690e+06  3.890670e+06
# winner_dividend          0.000000e+00  0.000000e+00  0.000000e+00
# year_earnings            0.000000e+00  1.200000e+05  7.650000e+05
#
#                                   max               0
# age                      1.600000e+01           int64
# category                          NaN        category
# code                              NaN          object
# condition_age                     NaN        category
# condition_sex                     NaN        category
# country                           NaN        category
# date                              NaN          object
# declared_player_count    2.400000e+01           int64
# distance                 6.856000e+03           int64
# earnings                 1.389165e+09           int64
# final_odds               5.446000e+02         float64
# final_odds_ref           9.990000e+02         float64
# final_odds_ref_inv       1.000000e+04         float64
# final_odds_ref_mean      4.680200e+02         float64
# final_odds_ref_r         4.079736e+00         float64
# final_odds_ref_std       1.000000e+04         float64
# handicap_distance        3.150000e+03         float64
# handicap_distance_mean   1.000000e+04         float64
# handicap_distance_r      1.000000e+04         float64
# handicap_distance_std    1.000000e+04         float64
# handicap_weight          7.100000e+01         float64
# handicap_weight_mean     1.000000e+04         float64
# handicap_weight_r        1.000000e+04         float64
# handicap_weight_std      1.000000e+04         float64
# herder_id                9.120000e+03         float64
# hippodrome_id            2.710000e+02           int64
# hist_1_pos               9.000000e+00         float64
# hist_1_pos_mean          7.333333e+00         float64
# hist_1_pos_r             1.000000e+04         float64
# hist_1_pos_std           4.654747e+00         float64
# ...                               ...             ...
# placed_dividend          4.610000e+03         float64
# placed_earnings          1.061760e+09           int64
# position                 2.200000e+01         float64
# post_position            2.400000e+01           int64
# prev_year_earnings       7.835376e+08           int64
# prev_year_earnings_mean  1.759502e+08         float64
# prev_year_earnings_r     1.000000e+04         float64
# prev_year_earnings_std   2.351094e+08         float64
# prize                    1.386022e+07           int64
# race_count               3.940000e+02           int64
# race_count_mean          1.391429e+02         float64
# race_count_r             1.000000e+04         float64
# race_count_std           1.234787e+02         float64
# race_id                  1.983000e+04           int64
# session_id               3.134000e+03           int64
# speed                    1.000000e+04         float64
# start_at                          NaN  datetime64[ns]
# sub_category                      NaN        category
# time                     3.379300e+05         float64
# trainer_id               8.834000e+03           int64
# victory_count            5.300000e+01           int64
# victory_count_mean       2.200000e+01         float64
# victory_count_r          1.000000e+04         float64
# victory_count_std        1.739333e+01         float64
# victory_earnings         1.389165e+09           int64
# victory_earnings_mean    2.979731e+08         float64
# victory_earnings_r       1.000000e+04         float64
# victory_earnings_std     3.848033e+08         float64
# winner_dividend          1.844000e+04         float64
# year_earnings            6.705090e+08           int64
#
# [125 rows x 9 columns]

# %%
def random_race(df, cols=None, n=1):

    if cols is None:
        cols = ['position', 'sub_category', 'num', 'final_odds', 'final_odds_ref_r', 'final_odds_ref', 'hist_1_pos', 'hist_1_pos_r', 'hist_1_pos_mean', 'hist_1_pos_std', 'odds_0', 'odds_1']

    return df.reset_index().set_index(['race_id', 'index']).loc[np.random.permutation(df['race_id'].unique())[0:n]][cols]

# %%
random_race(df)
# Out:
#                 position sub_category  num  final_odds  final_odds_ref_r  \
# race_id index
# 18805   131964       7.0     HANDICAP    1         4.8         -0.818578
#         131965       1.0     HANDICAP    2         7.5         -0.125083
#         131966       5.0     HANDICAP    3         3.4         -0.400581
#         131967       3.0     HANDICAP    4        27.3          0.421164
#         131968       4.0     HANDICAP    5         2.2         -0.870828
#         131969       2.0     HANDICAP    6       118.3               NaN
#         131970       6.0     HANDICAP    7        15.4          1.793906
#
#                 final_odds_ref  hist_1_pos  hist_1_pos_r  hist_1_pos_mean  \
# race_id index
# 18805   131964             2.7         0.0     -1.380585         3.714286
#         131965            17.3         5.0      0.477895         3.714286
#         131966            11.5         1.0     -1.008889         3.714286
#         131967            28.8         4.0      0.106199         3.714286
#         131968             1.6         3.0     -0.265497         3.714286
#         131969             NaN         8.0      1.592983         3.714286
#         131970            57.7         5.0      0.477895         3.714286
#
#                 hist_1_pos_std  odds_0  odds_1
# race_id index
# 18805   131964        2.690371     1.6     2.7
#         131965        2.690371     1.6     2.7
#         131966        2.690371     1.6     2.7
#         131967        2.690371     1.6     2.7
#         131968        2.690371     1.6     2.7
#         131969        2.690371     1.6     2.7
#         131970        2.690371     1.6     2.7

# %%
features = agg_features

features = features + ['declared_player_count'] + ['hist_{}_pos'.format(i+1) for i in range(6)]

features = features + ['odds_{:d}'.format(i) for i in range(10)]

#features = ['odds_{:d}'.format(i) for i in range(10)]

features
# Out:
# ['race_count_r',
#  'victory_count_r',
#  'placed_2_count_r',
#  'placed_3_count_r',
#  'victory_earnings_r',
#  'prev_year_earnings_r',
#  'handicap_distance_r',
#  'handicap_weight_r',
#  'hist_1_pos_r',
#  'hist_2_pos_r',
#  'hist_3_pos_r',
#  'hist_4_pos_r',
#  'hist_5_pos_r',
#  'hist_6_pos_r',
#  'race_count_std',
#  'victory_count_std',
#  'placed_2_count_std',
#  'placed_3_count_std',
#  'victory_earnings_std',
#  'prev_year_earnings_std',
#  'handicap_distance_std',
#  'handicap_weight_std',
#  'final_odds_ref_std',
#  'hist_1_pos_std',
#  'hist_2_pos_std',
#  'hist_3_pos_std',
#  'hist_4_pos_std',
#  'hist_5_pos_std',
#  'hist_6_pos_std',
#  'race_count_mean',
#  'victory_count_mean',
#  'placed_2_count_mean',
#  'placed_3_count_mean',
#  'victory_earnings_mean',
#  'prev_year_earnings_mean',
#  'handicap_distance_mean',
#  'handicap_weight_mean',
#  'final_odds_ref_mean',
#  'hist_1_pos_mean',
#  'hist_2_pos_mean',
#  'hist_3_pos_mean',
#  'hist_4_pos_mean',
#  'hist_5_pos_mean',
#  'hist_6_pos_mean',
#  'declared_player_count',
#  'hist_1_pos',
#  'hist_2_pos',
#  'hist_3_pos',
#  'hist_4_pos',
#  'hist_5_pos',
#  'hist_6_pos',
#  'odds_0',
#  'odds_1',
#  'odds_2',
#  'odds_3',
#  'odds_4',
#  'odds_5',
#  'odds_6',
#  'odds_7',
#  'odds_8',
#  'odds_9']

# %%
pd.options.display.max_columns = 200

# %%
random_race(df, ['final_odds_ref', 'winner_dividend'] + features)
# Out:
#                final_odds_ref  winner_dividend  race_count_r  victory_count_r  \
# race_id index
# 3452    23628             3.1              0.0      0.618590         0.053774
#         23629            11.3              0.0     -1.360897        -0.914166
#         23630             5.8              0.0      0.288675         1.667008
#         23631            16.9              0.0     -0.646082        -0.268872
#         23632            16.3              0.0     -0.756054        -0.591519
#         23633            32.2              0.0      1.718304         2.312302
#         23634            14.5              0.0      1.278418         0.376421
#         23635            22.5              0.0     -0.975997        -0.591519
#         23636             6.2            690.0      1.113461        -0.268872
#         23637            17.8              0.0     -0.701068        -0.591519
#         23638            22.7              0.0      0.068732        -0.591519
#         23639            13.7              0.0     -0.646082        -0.591519
#
#                placed_2_count_r  placed_3_count_r  victory_earnings_r  \
# race_id index
# 3452    23628          0.866298          1.608681            1.732188
#         23629         -0.662463         -1.305157           -0.926256
#         23630          0.560546          0.515992            0.903331
#         23631         -0.356711         -0.576697           -0.463317
#         23632         -0.968215         -0.576697           -0.682398
#         23633          1.477802          0.515992            0.247392
#         23634          1.783555         -0.212467            1.460266
#         23635         -0.968215         -0.940927           -0.957554
#         23636          0.560546          1.972911            0.882466
#         23637         -0.968215         -0.576697           -0.862619
#         23638         -0.662463          0.151762           -0.418979
#         23639         -0.662463         -0.576697           -0.914520
#
#                prev_year_earnings_r  handicap_distance_r  handicap_weight_r  \
# race_id index
# 3452    23628              2.083240              10000.0           1.344362
#         23629             -0.250064              10000.0           1.344362
#         23630              1.276099              10000.0           1.021715
#         23631              0.129602              10000.0           0.699068
#         23632             -0.517236              10000.0           0.376421
#         23633             -1.187510              10000.0           0.376421
#         23634              0.860810              10000.0           0.053774
#         23635             -1.196885              10000.0          -0.914166
#         23636              0.204598              10000.0          -0.914166
#         23637             -0.354120              10000.0          -0.914166
#         23638             -0.086011              10000.0          -1.236813
#         23639             -0.962523              10000.0          -1.236813
#
#                hist_1_pos_r  hist_2_pos_r  hist_3_pos_r  hist_4_pos_r  \
# race_id index
# 3452    23628     -0.337721      0.777805      1.176685     -0.349603
#         23629      1.463457     -1.088927     -1.424409      0.000000
#         23630     -0.788015     -1.088927     -0.681239     -1.398412
#         23631     -1.238309      1.151151      0.433516      0.349603
#         23632     -1.688604     -0.715581     -0.309654      0.349603
#         23633      0.562868     -1.088927      0.061931      1.398412
#         23634     -0.337721     -0.715581      0.805101      0.000000
#         23635      0.562868      0.777805     -1.052824     -0.349603
#         23636      1.013162     -0.342234      0.061931      1.748015
#         23637      0.562868      0.404459     -1.424409     -1.398412
#         23638      1.013162      1.897844      1.548270      0.699206
#         23639     -0.788015      0.031112      0.805101     -1.048809
#
#                hist_5_pos_r  hist_6_pos_r  race_count_std  victory_count_std  \
# race_id index
# 3452    23628     -1.587863      1.608681       18.186533           3.099365
#         23629     -0.982963     -0.576697       18.186533           3.099365
#         23630      1.134188      0.151762       18.186533           3.099365
#         23631      0.226838     -1.305157       18.186533           3.099365
#         23632      0.529288      1.244452       18.186533           3.099365
#         23633      1.134188     -0.940927       18.186533           3.099365
#         23634      0.226838      0.515992       18.186533           3.099365
#         23635     -1.587863     -0.576697       18.186533           3.099365
#         23636     -0.075613     -0.212467       18.186533           3.099365
#         23637     -0.680513     -1.305157       18.186533           3.099365
#         23638      0.529288      1.244452       18.186533           3.099365
#         23639      1.134188      0.151762       18.186533           3.099365
#
#                placed_2_count_std  placed_3_count_std  victory_earnings_std  \
# race_id index
# 3452    23628            3.270622             2.74552          3.834198e+06
#         23629            3.270622             2.74552          3.834198e+06
#         23630            3.270622             2.74552          3.834198e+06
#         23631            3.270622             2.74552          3.834198e+06
#         23632            3.270622             2.74552          3.834198e+06
#         23633            3.270622             2.74552          3.834198e+06
#         23634            3.270622             2.74552          3.834198e+06
#         23635            3.270622             2.74552          3.834198e+06
#         23636            3.270622             2.74552          3.834198e+06
#         23637            3.270622             2.74552          3.834198e+06
#         23638            3.270622             2.74552          3.834198e+06
#         23639            3.270622             2.74552          3.834198e+06
#
#                prev_year_earnings_std  handicap_distance_std  \
# race_id index
# 3452    23628            1.066728e+06                10000.0
#         23629            1.066728e+06                10000.0
#         23630            1.066728e+06                10000.0
#         23631            1.066728e+06                10000.0
#         23632            1.066728e+06                10000.0
#         23633            1.066728e+06                10000.0
#         23634            1.066728e+06                10000.0
#         23635            1.066728e+06                10000.0
#         23636            1.066728e+06                10000.0
#         23637            1.066728e+06                10000.0
#         23638            1.066728e+06                10000.0
#         23639            1.066728e+06                10000.0
#
#                handicap_weight_std  final_odds_ref_std  hist_1_pos_std  \
# race_id index
# 3452    23628             3.099365            8.219102         2.22077
#         23629             3.099365            8.219102         2.22077
#         23630             3.099365            8.219102         2.22077
#         23631             3.099365            8.219102         2.22077
#         23632             3.099365            8.219102         2.22077
#         23633             3.099365            8.219102         2.22077
#         23634             3.099365            8.219102         2.22077
#         23635             3.099365            8.219102         2.22077
#         23636             3.099365            8.219102         2.22077
#         23637             3.099365            8.219102         2.22077
#         23638             3.099365            8.219102         2.22077
#         23639             3.099365            8.219102         2.22077
#
#                hist_2_pos_std  hist_3_pos_std  hist_4_pos_std  hist_5_pos_std  \
# race_id index
# 3452    23628        2.678478        2.691175        2.860388         3.30633
#         23629        2.678478        2.691175        2.860388         3.30633
#         23630        2.678478        2.691175        2.860388         3.30633
#         23631        2.678478        2.691175        2.860388         3.30633
#         23632        2.678478        2.691175        2.860388         3.30633
#         23633        2.678478        2.691175        2.860388         3.30633
#         23634        2.678478        2.691175        2.860388         3.30633
#         23635        2.678478        2.691175        2.860388         3.30633
#         23636        2.678478        2.691175        2.860388         3.30633
#         23637        2.678478        2.691175        2.860388         3.30633
#         23638        2.678478        2.691175        2.860388         3.30633
#         23639        2.678478        2.691175        2.860388         3.30633
#
#                hist_6_pos_std  race_count_mean  victory_count_mean  \
# race_id index
# 3452    23628         2.74552            30.75            2.833333
#         23629         2.74552            30.75            2.833333
#         23630         2.74552            30.75            2.833333
#         23631         2.74552            30.75            2.833333
#         23632         2.74552            30.75            2.833333
#         23633         2.74552            30.75            2.833333
#         23634         2.74552            30.75            2.833333
#         23635         2.74552            30.75            2.833333
#         23636         2.74552            30.75            2.833333
#         23637         2.74552            30.75            2.833333
#         23638         2.74552            30.75            2.833333
#         23639         2.74552            30.75            2.833333
#
#                placed_2_count_mean  placed_3_count_mean  \
# race_id index
# 3452    23628             4.166667             3.583333
#         23629             4.166667             3.583333
#         23630             4.166667             3.583333
#         23631             4.166667             3.583333
#         23632             4.166667             3.583333
#         23633             4.166667             3.583333
#         23634             4.166667             3.583333
#         23635             4.166667             3.583333
#         23636             4.166667             3.583333
#         23637             4.166667             3.583333
#         23638             4.166667             3.583333
#         23639             4.166667             3.583333
#
#                victory_earnings_mean  prev_year_earnings_mean  \
# race_id index
# 3452    23628              4701450.0                1416750.0
#         23629              4701450.0                1416750.0
#         23630              4701450.0                1416750.0
#         23631              4701450.0                1416750.0
#         23632              4701450.0                1416750.0
#         23633              4701450.0                1416750.0
#         23634              4701450.0                1416750.0
#         23635              4701450.0                1416750.0
#         23636              4701450.0                1416750.0
#         23637              4701450.0                1416750.0
#         23638              4701450.0                1416750.0
#         23639              4701450.0                1416750.0
#
#                handicap_distance_mean  handicap_weight_mean  \
# race_id index
# 3452    23628                 10000.0             24.833333
#         23629                 10000.0             24.833333
#         23630                 10000.0             24.833333
#         23631                 10000.0             24.833333
#         23632                 10000.0             24.833333
#         23633                 10000.0             24.833333
#         23634                 10000.0             24.833333
#         23635                 10000.0             24.833333
#         23636                 10000.0             24.833333
#         23637                 10000.0             24.833333
#         23638                 10000.0             24.833333
#         23639                 10000.0             24.833333
#
#                final_odds_ref_mean  hist_1_pos_mean  hist_2_pos_mean  \
# race_id index
# 3452    23628                15.25             3.75         2.916667
#         23629                15.25             3.75         2.916667
#         23630                15.25             3.75         2.916667
#         23631                15.25             3.75         2.916667
#         23632                15.25             3.75         2.916667
#         23633                15.25             3.75         2.916667
#         23634                15.25             3.75         2.916667
#         23635                15.25             3.75         2.916667
#         23636                15.25             3.75         2.916667
#         23637                15.25             3.75         2.916667
#         23638                15.25             3.75         2.916667
#         23639                15.25             3.75         2.916667
#
#                hist_3_pos_mean  hist_4_pos_mean  hist_5_pos_mean  \
# race_id index
# 3452    23628         3.833333              4.0             5.25
#         23629         3.833333              4.0             5.25
#         23630         3.833333              4.0             5.25
#         23631         3.833333              4.0             5.25
#         23632         3.833333              4.0             5.25
#         23633         3.833333              4.0             5.25
#         23634         3.833333              4.0             5.25
#         23635         3.833333              4.0             5.25
#         23636         3.833333              4.0             5.25
#         23637         3.833333              4.0             5.25
#         23638         3.833333              4.0             5.25
#         23639         3.833333              4.0             5.25
#
#                hist_6_pos_mean  declared_player_count  hist_1_pos  hist_2_pos  \
# race_id index
# 3452    23628         3.583333                     12         3.0         5.0
#         23629         3.583333                     12         7.0         0.0
#         23630         3.583333                     12         2.0         0.0
#         23631         3.583333                     12         1.0         6.0
#         23632         3.583333                     12         0.0         1.0
#         23633         3.583333                     12         5.0         0.0
#         23634         3.583333                     12         3.0         1.0
#         23635         3.583333                     12         5.0         5.0
#         23636         3.583333                     12         6.0         2.0
#         23637         3.583333                     12         5.0         4.0
#         23638         3.583333                     12         6.0         8.0
#         23639         3.583333                     12         2.0         3.0
#
#                hist_3_pos  hist_4_pos  hist_5_pos  hist_6_pos  odds_0  odds_1  \
# race_id index
# 3452    23628         7.0         3.0         0.0         8.0     3.1     5.8
#         23629         0.0         4.0         2.0         2.0     3.1     5.8
#         23630         2.0         0.0         9.0         4.0     3.1     5.8
#         23631         5.0         5.0         6.0         0.0     3.1     5.8
#         23632         3.0         5.0         7.0         7.0     3.1     5.8
#         23633         4.0         8.0         9.0         1.0     3.1     5.8
#         23634         6.0         4.0         6.0         5.0     3.1     5.8
#         23635         1.0         3.0         0.0         2.0     3.1     5.8
#         23636         4.0         9.0         5.0         3.0     3.1     5.8
#         23637         0.0         0.0         3.0         0.0     3.1     5.8
#         23638         8.0         6.0         7.0         7.0     3.1     5.8
#         23639         6.0         1.0         9.0         4.0     3.1     5.8
#
#                odds_2  odds_3  odds_4  odds_5  odds_6  odds_7  odds_8  odds_9
# race_id index
# 3452    23628     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23629     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23630     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23631     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23632     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23633     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23634     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23635     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23636     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23637     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23638     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5
#         23639     6.2    11.3    13.7    14.5    16.3    16.9    17.8    22.5

# %%
N_TARGETS = 20

df['target'] = np.log(1.+df['position'].copy())
df.loc[df['target'] > N_TARGETS, 'target'] = np.log(1.+N_TARGETS)
df['target'].fillna(NAN_FLAG, inplace=True)

#df['target'] = df['final_odds_ref'].fillna(df['final_odds_ref'].mean())

#df['target'] = df['winner_dividend'].fillna(0.)

#df['target'].fillna( NAN_FLAG, inplace=True )


#df['target'] = df['winner_dividend']/100.

#df['target'].fillna(NAN_FLAG, inplace=True)

df['target'] = df['winner_dividend'].fillna(0.)/100.

df['target'].hist()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.metrics import log_loss, mean_absolute_error
from sklearn.model_selection import KFold, GroupKFold
from sklearn.preprocessing import MinMaxScaler, Normalizer, StandardScaler

groups = df['race_id'].values

group_kfold = GroupKFold(n_splits=2)

splits = list(group_kfold.split(df.values, df['position'].values, groups))

from cataclop.ml import preprocessing

models = [
    {
        'name': 'knn_5',
        'model': KNeighborsRegressor(n_neighbors=5),
        'scaler': True
    },
    {
        'name': 'knn_10',
        'model': KNeighborsRegressor(n_neighbors=10),
        'scaler': True
    },
    {
        'name': 'knn_30',
        'model': KNeighborsRegressor(n_neighbors=30),
        'scaler': True
    },
    {
        'name': 'knn_90',
        'model': KNeighborsRegressor(n_neighbors=150),
        'scaler': True
    },
    {
        'name': 'rf_10',
        'model': RandomForestRegressor(n_estimators=10),
        'scaler': False
    },
    {
        'name': 'rf_100',
        'model': RandomForestRegressor(n_estimators=100),
        'scaler': False
    },
]

for model in models:
    for i in range(N_TARGETS):
        df['pred_{}_{}'.format(model['name'], i+1)] = 0.0
        df_test['pred_{}_{}'.format(model['name'], i+1)] = 0.0

# %%
for train_index, test_index in splits:
    
    for model in models:

        X_train = df[features].iloc[train_index].copy()
        y_train = df['target'].iloc[train_index]

        dummies = preprocessing.get_dummies(df.iloc[train_index], ['sub_category'])
        X_train = pd.concat([X_train, preprocessing.get_dummy_values(df.iloc[train_index], dummies)], axis=1)

        X_train = X_train[ (df.iloc[train_index]['target'] != NAN_FLAG) & (df.iloc[train_index]['final_odds_ref'] < 20) ]
        y_train = df['target'].iloc[train_index][ (df.iloc[train_index]['target'] != NAN_FLAG) & (df.iloc[train_index]['final_odds_ref'] < 20) ]

        X_test = df[features].iloc[test_index].copy()
        y_test = df['target'].iloc[test_index]
    
        X_val = df_test[features].copy()

        X_test = pd.concat([X_test, preprocessing.get_dummy_values(df.iloc[test_index], dummies)], axis=1)
        X_val = pd.concat([X_val, preprocessing.get_dummy_values(df_test, dummies)], axis=1)

        X_train = X_train.values
        X_test = X_test.values
        X_val = X_val.values

        idx = df.iloc[test_index].index

        if model['scaler']:
            scaler = StandardScaler()
            scaler.fit(X_train)

            X_train = scaler.transform(X_train)
            X_test = scaler.transform(X_test)
            #X_val = scaler.transform(X_val)

        clf = model['model']
        clf.fit(X_train, y_train.values)

        '''
        p = clf.predict_proba(X_test)
    
        print( model['name'], log_loss(y_test.values, p) )

        for i in range(N_TARGETS):
            df.loc[idx, 'pred_{}_{}'.format(model['name'], i+1)] = p[:, list(clf.classes_).index(i+1)]

        p = clf.predict_proba(X_val)
    
        for i in range(N_TARGETS):
            df_test['pred_{}_{}'.format(model['name'], i+1)] = p[:, list(clf.classes_).index(i+1)]
        '''
        
        p = clf.predict(X_test)
        
        df.loc[idx, 'pred_{}_1'.format(model['name'])] = p
        
        print( model['name'], mean_absolute_error(y_test.values, p) )
# Out:
# knn_5 1.4795148904289193
# knn_10 1.4738527814197415
# knn_30 1.4656112255728286
# knn_90 1.466316051695074
# rf_10 1.7567167574792693
# rf_100 1.748085296657152
# knn_5 1.4386192170818504
# knn_10 1.441857463944559
# knn_30 1.444917649996878
# knn_90 1.4399372416807141
# rf_10 1.7686259371333544
# rf_100 1.7755490683421697

# %%
races = df.groupby('race_id')

N_TARGETS = 1

agg_preds = []

for i in range(N_TARGETS):
    for model in models:
        for s in ['mean', 'std', 'r']:
            col = 'pred_{}_{}_{}'.format(model['name'], i+1, s)
            if col in df.columns:
                df.drop(col, axis=1, inplace=True)
        
for i in range(N_TARGETS):
    for model in models:
        col = 'pred_{}_{}'.format(model['name'], i+1)
        agg_preds.append(col)
        
stats = races[agg_preds].agg([np.mean, np.std])
stats.columns = ['_'.join(col) for col in stats.columns.values]

df = df.join(stats, how='left', on='race_id')

for f in agg_preds:
    col = '{}_r'.format(f)
    df[col] = df[f] - df['{}_mean'.format(f)] / df['{}_std'.format(f)]
    
agg_preds = ['{}_r'.format(f) for f in agg_preds] + ['{}_std'.format(f) for f in agg_preds] + ['{}_mean'.format(f) for f in agg_preds]

df[agg_preds] = df[agg_preds].replace([np.inf, -np.inf], np.nan)
df[agg_preds] = df[agg_preds].fillna(NAN_FLAG)

# %%
random_race(df, ['final_odds', 'position', 'final_odds_ref', 'final_odds', 'target'] + ['pred_{}_1'.format(model['name']) for model in models] +  ['pred_{}_1_mean'.format(model['name']) for model in models])
# Out:
#                final_odds  position  final_odds_ref  final_odds  target  \
# race_id index
# 5754    39846         9.3       7.0             7.5         9.3     0.0
#         39848        37.9       6.0            40.0        37.9     0.0
#         39849         7.9       1.0            17.6         7.9     9.6
#         39850        16.2       NaN            14.2        16.2     0.0
#         39851        77.4       NaN            33.7        77.4     0.0
#         39852        51.0       NaN            12.8        51.0     0.0
#         39853        26.8       4.0             9.3        26.8     0.0
#         39854         1.9       3.0             2.8         1.9     0.0
#         39855        61.6       2.0            35.8        61.6     0.0
#         39856        43.4       NaN            33.7        43.4     0.0
#         39857        10.9       5.0             9.6        10.9     0.0
#         39858        20.4       8.0            10.6        20.4     0.0
#         39859        11.5       NaN            12.8        11.5     0.0
#         39860       100.0       NaN            60.1       100.0     0.0
#
#                pred_knn_5_1  pred_knn_10_1  pred_knn_30_1  pred_knn_90_1  \
# race_id index
# 5754    39846          1.60           1.31       1.066667       0.887333
#         39848          1.60           0.80       0.446667       0.964667
#         39849          3.96           1.98       1.190000       1.077333
#         39850          3.96           1.98       1.176667       0.888000
#         39851          3.96           1.98       1.176667       0.888000
#         39852          3.96           1.98       1.176667       0.888000
#         39853          1.38           1.25       1.873333       0.911333
#         39854          0.00           0.00       1.450000       0.872667
#         39855          2.62           1.31       0.660000       0.586667
#         39856          3.96           1.98       1.190000       1.086000
#         39857          0.00           0.00       0.266667       0.899333
#         39858          1.68           1.13       1.463333       0.740000
#         39859          3.96           1.98       1.000000       0.942667
#         39860          1.60           0.80       0.676667       0.837333
#
#                pred_rf_10_1  pred_rf_100_1  pred_knn_5_1_mean  \
# race_id index
# 5754    39846          0.00       1.376000           2.445714
#         39848          2.26       0.904000           2.445714
#         39849          0.24       0.752333           2.445714
#         39850          0.48       0.652000           2.445714
#         39851          0.00       1.025000           2.445714
#         39852          1.60       1.144000           2.445714
#         39853          1.77       1.007000           2.445714
#         39854          0.00       1.279333           2.445714
#         39855          3.88       1.197000           2.445714
#         39856          1.77       0.974000           2.445714
#         39857          2.22       1.455000           2.445714
#         39858          9.97       1.210000           2.445714
#         39859          1.81       1.330000           2.445714
#         39860          0.80       1.345000           2.445714
#
#                pred_knn_10_1_mean  pred_knn_30_1_mean  pred_knn_90_1_mean  \
# race_id index
# 5754    39846                1.32            1.058095            0.890667
#         39848                1.32            1.058095            0.890667
#         39849                1.32            1.058095            0.890667
#         39850                1.32            1.058095            0.890667
#         39851                1.32            1.058095            0.890667
#         39852                1.32            1.058095            0.890667
#         39853                1.32            1.058095            0.890667
#         39854                1.32            1.058095            0.890667
#         39855                1.32            1.058095            0.890667
#         39856                1.32            1.058095            0.890667
#         39857                1.32            1.058095            0.890667
#         39858                1.32            1.058095            0.890667
#         39859                1.32            1.058095            0.890667
#         39860                1.32            1.058095            0.890667
#
#                pred_rf_10_1_mean  pred_rf_100_1_mean
# race_id index
# 5754    39846           1.914286            1.117905
#         39848           1.914286            1.117905
#         39849           1.914286            1.117905
#         39850           1.914286            1.117905
#         39851           1.914286            1.117905
#         39852           1.914286            1.117905
#         39853           1.914286            1.117905
#         39854           1.914286            1.117905
#         39855           1.914286            1.117905
#         39856           1.914286            1.117905
#         39857           1.914286            1.117905
#         39858           1.914286            1.117905
#         39859           1.914286            1.117905
#         39860           1.914286            1.117905

# %%
features
# Out:
# ['race_count_r',
#  'victory_count_r',
#  'placed_2_count_r',
#  'placed_3_count_r',
#  'victory_earnings_r',
#  'prev_year_earnings_r',
#  'handicap_distance_r',
#  'handicap_weight_r',
#  'hist_1_pos_r',
#  'hist_2_pos_r',
#  'hist_3_pos_r',
#  'hist_4_pos_r',
#  'hist_5_pos_r',
#  'hist_6_pos_r',
#  'race_count_std',
#  'victory_count_std',
#  'placed_2_count_std',
#  'placed_3_count_std',
#  'victory_earnings_std',
#  'prev_year_earnings_std',
#  'handicap_distance_std',
#  'handicap_weight_std',
#  'final_odds_ref_std',
#  'hist_1_pos_std',
#  'hist_2_pos_std',
#  'hist_3_pos_std',
#  'hist_4_pos_std',
#  'hist_5_pos_std',
#  'hist_6_pos_std',
#  'race_count_mean',
#  'victory_count_mean',
#  'placed_2_count_mean',
#  'placed_3_count_mean',
#  'victory_earnings_mean',
#  'prev_year_earnings_mean',
#  'handicap_distance_mean',
#  'handicap_weight_mean',
#  'final_odds_ref_mean',
#  'hist_1_pos_mean',
#  'hist_2_pos_mean',
#  'hist_3_pos_mean',
#  'hist_4_pos_mean',
#  'hist_5_pos_mean',
#  'hist_6_pos_mean',
#  'declared_player_count',
#  'hist_1_pos',
#  'hist_2_pos',
#  'hist_3_pos',
#  'hist_4_pos',
#  'hist_5_pos',
#  'hist_6_pos',
#  'odds_0',
#  'odds_1',
#  'odds_2',
#  'odds_3',
#  'odds_4',
#  'odds_5',
#  'odds_6',
#  'odds_7',
#  'odds_8',
#  'odds_9']

# %%
stacked_features = ['final_odds_ref', 'declared_player_count', 'final_odds_ref_std', 'final_odds_ref_mean', 'race_count_mean', 'race_count_std'] + ['odds_{:d}'.format(i) for i in range(10)]
df['final_odds_ref'].fillna(NAN_FLAG, inplace=True)

for i in range(N_TARGETS):
    stacked_features = stacked_features + ['pred_{}_{}'.format(model['name'], i+1) for model in models]
    
stacked_features = stacked_features + agg_preds# + ['gp_feat_{}'.format(i+1) for i in range(N_GP_FEATURES)]

stacked_features = stacked_features

stacked_features
# Out:
# ['final_odds_ref',
#  'declared_player_count',
#  'final_odds_ref_std',
#  'final_odds_ref_mean',
#  'race_count_mean',
#  'race_count_std',
#  'odds_0',
#  'odds_1',
#  'odds_2',
#  'odds_3',
#  'odds_4',
#  'odds_5',
#  'odds_6',
#  'odds_7',
#  'odds_8',
#  'odds_9',
#  'pred_knn_5_1',
#  'pred_knn_10_1',
#  'pred_knn_30_1',
#  'pred_knn_90_1',
#  'pred_rf_10_1',
#  'pred_rf_100_1',
#  'pred_knn_5_1_r',
#  'pred_knn_10_1_r',
#  'pred_knn_30_1_r',
#  'pred_knn_90_1_r',
#  'pred_rf_10_1_r',
#  'pred_rf_100_1_r',
#  'pred_knn_5_1_std',
#  'pred_knn_10_1_std',
#  'pred_knn_30_1_std',
#  'pred_knn_90_1_std',
#  'pred_rf_10_1_std',
#  'pred_rf_100_1_std',
#  'pred_knn_5_1_mean',
#  'pred_knn_10_1_mean',
#  'pred_knn_30_1_mean',
#  'pred_knn_90_1_mean',
#  'pred_rf_10_1_mean',
#  'pred_rf_100_1_mean']

# %%
from sklearn.linear_model import LogisticRegression
from gplearn.genetic import SymbolicRegressor

N_TARGETS_STACKED = 20

df['target_stacked'] = df['position'].copy()

'''
df['target_stacked'] = df['target_stacked'] / df['declared_player_count']
df['target_stacked'].fillna(df['target_stacked'].mean(), inplace=True)
df['target_stacked'] = np.exp(1. + df['target_stacked'])
'''


#df['target_stacked'] = df['target_stacked'].apply(lambda r: 1 if r >= 1 and r <= 2 else r-1 if r > 2 else r  )

df.loc[df['target_stacked'] > N_TARGETS_STACKED, 'target_stacked'] = N_TARGETS_STACKED
df['target_stacked'].fillna(N_TARGETS_STACKED, inplace=True)

df['target_stacked'] = df['target_stacked'].apply(lambda v: -1000 if v == 1 else v)


df['pred_stacked'] = 0.0
for i in range(N_TARGETS_STACKED):
    df['pred_stacked_{}'.format(i+1)] = 0.0
    df_test['pred_stacked_{}'.format(i+1)] = 0.0

#df['target_stacked'] = np.ceil(1.+df['position'].fillna( 0. ))

df['target_stacked'] = np.log(1.+df['winner_dividend'].fillna(0.)/100)

#df['target_stacked'] = df['target'].copy()

df['target_stacked'].describe()
# Out:
# count    106780.000000
# mean          0.173450
# std           0.599315
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           5.222516
# Name: target_stacked, dtype: float64

# %%
np.log(1)
# Out:
# 0.0

# %%
df['target_stacked'].describe()
# Out:
# count    106780.000000
# mean         77.619404
# std         408.173569
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max       18440.000000
# Name: target_stacked, dtype: float64

# %%
from sklearn import linear_model

for train_index, test_index in splits:

    X_train = df[stacked_features].iloc[train_index].copy()
    y_train = df['target_stacked'].iloc[train_index]

    dummies = preprocessing.get_dummies(df.iloc[train_index], ['sub_category'])
    X_train = pd.concat([X_train, preprocessing.get_dummy_values(df.iloc[train_index], dummies)], axis=1)
    
    X_train = X_train[(df.iloc[train_index]['target_stacked'] != NAN_FLAG) & (df.iloc[train_index]['sub_category'] != 'h') & ((df.iloc[train_index]['position'] == 2) | ((df.iloc[train_index]['final_odds_ref'] < 20) & (df.iloc[train_index]['position'] == 1))) ]
    y_train = df['target_stacked'].iloc[train_index][(df.iloc[train_index]['target_stacked'] != NAN_FLAG) & (df.iloc[train_index]['sub_category'] != 'g') & ((df.iloc[train_index]['position'] == 2) | ((df.iloc[train_index]['final_odds_ref'] < 20) & (df.iloc[train_index]['position'] == 1))) ]

    X_test = df[stacked_features].iloc[test_index].copy()
    y_test = df['target_stacked'].iloc[test_index]
    
    #X_val = df_test[stacked_features].copy()

    X_test = pd.concat([X_test, preprocessing.get_dummy_values(df.iloc[test_index], dummies)], axis=1)
    #X_val = pd.concat([X_val, preprocessing.get_dummy_values(df_test, dummies)], axis=1)

    X_train = X_train.values
    X_test = X_test.values
    #X_val = X_val.values

    idx = df.iloc[test_index].index
    
    scaler = StandardScaler()
    scaler.fit(X_train)

    
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    #X_val = scaler.transform(X_val)
    
    '''
    clf = MLPClassifier(hidden_layer_sizes=(100), activation='tanh', batch_size=20)
    #clf = RandomForestClassifier(n_estimators=150)
    #clf = AdaBoostClassifier(n_estimators=250)
    #clf = SVC(probability=True)
    #clf = KNeighborsClassifier(n_neighbors=25)

    clf.fit(X_train, y_train.values)
    
    p = clf.predict_proba(X_test)
    
    print( log_loss(y_test.values, p) )

    df.loc[idx, 'pred_stacked'] = p[:, list(clf.classes_).index(1)]
    for i in range(N_TARGETS_STACKED):
        df.loc[idx, 'pred_stacked_{}'.format(i+1)] = p[:, list(clf.classes_).index(i+1)]

    #p = clf.predict_proba(X_val)
    
    #for i in range(N_TARGETS_STACKED):
    #    df_test['pred_stacked_{}'.format(i+1)] = p[:, list(clf.classes_).index(i+1)]
    
    '''
       
    from sklearn.neighbors import KNeighborsRegressor
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.svm import SVR
    
    from sklearn.ensemble import GradientBoostingRegressor
    from gplearn.genetic import SymbolicRegressor
    
    #reg = GradientBoostingRegressor()
    
    #reg = linear_model.LinearRegression()
    #reg = SVR()
    #reg1 = MLPRegressor(hidden_layer_sizes=(30), activation='tanh')
    #reg2 = RandomForestRegressor(n_estimators=100)
    #reg3 = KNeighborsRegressor(n_neighbors=10, weights='distance')
    '''
    reg4 = SymbolicRegressor(verbose=True, 
                             function_set=('add', 'mul', 'div', 'sub', 'sin', 'tan', 'abs', 'neg', 'log'),
                             parsimony_coefficient=0,
                             p_crossover=0.7,
                             p_subtree_mutation=0.1,
                             p_point_mutation=0.1
                            )

    function_set = ['add', 'sub', 'mul', 'div',
                'sqrt', 'log', 'abs', 'neg', 'inv', 'cos', 'sin',
                'max', 'min']
                    '''
    
    '''
    from gplearn.fitness import make_fitness
    
    def _metric(y, y_pred, w):
        
        diffs = np.abs(np.divide((np.maximum(0.001, y) - np.maximum(0.001, y_pred)),
                             np.maximum(0.001, y)))
        return 100. * np.average(diffs, weights=w)        
    
    metric = make_fitness(_metric, greater_is_better=False)
    
    reg = SymbolicRegressor(function_set=function_set, 
                            verbose=True,
                            const_range=(-100, 100),
                            parsimony_coefficient=0.00001,
                            max_samples=0.8, metric=metric)
                        '''
    
    reg1.fit(X_train, y_train.values)
    reg2.fit(X_train, y_train.values)
    reg3.fit(X_train, y_train.values)
    #reg4.fit(X_train, y_train.values)
    
    p = reg1.predict(X_test)
    df.loc[idx, 'pred_stacked_1'] = p
    
    p = reg2.predict(X_test)
    df.loc[idx, 'pred_stacked_2'] = p
    
    p = reg3.predict(X_test)
    df.loc[idx, 'pred_stacked_3'] = p
    
    #p = reg4.predict(X_test)
    #df.loc[idx, 'pred_stacked_4'] = p
    
    print( mean_absolute_error(y_test.values, p) )
# Out:
# 0.9121141571405148
# 0.9092296665988818

# %%
df['pred_stacked'] = df['pred_stacked_1'] + df['pred_stacked_2'] + df['pred_stacked_3']

# %%
random_race(df, cols=['position', 'final_odds_ref', 'winner_dividend', 'sub_category', 'target_stacked', 'pred_stacked', 'pred_stacked_1', 'pred_stacked_2', 'pred_stacked_3', 'pred_stacked_4']).sort_values('pred_stacked')
# Out:
#                position  final_odds_ref  winner_dividend         sub_category  \
# race_id index
# 13691   95988       3.0            12.4              0.0  COURSE_A_CONDITIONS
#         95986       4.0            16.9              0.0  COURSE_A_CONDITIONS
#         95982       7.0             7.4              0.0  COURSE_A_CONDITIONS
#         95989       9.0             4.9              0.0  COURSE_A_CONDITIONS
#         95985       5.0             4.6              0.0  COURSE_A_CONDITIONS
#         95981       6.0             9.3              0.0  COURSE_A_CONDITIONS
#         95983      10.0            10.0              0.0  COURSE_A_CONDITIONS
#         95987       1.0            12.6            930.0  COURSE_A_CONDITIONS
#         95984       2.0            19.4              0.0  COURSE_A_CONDITIONS
#         95990       8.0             6.9              0.0  COURSE_A_CONDITIONS
#
#                target_stacked  pred_stacked  pred_stacked_1  pred_stacked_2  \
# race_id index
# 13691   95988        0.000000      2.588507        1.065655        1.158401
#         95986        0.000000      2.720184        1.069339        1.308796
#         95982        0.000000      2.721885        1.280778        1.128318
#         95989        0.000000      2.862867        0.884729        0.917879
#         95985        0.000000      2.887771        1.024692        0.749453
#         95981        0.000000      3.069490        1.149557        1.346667
#         95983        0.000000      3.088078        1.049850        1.269457
#         95987        2.332144      3.211025        1.085884        1.058794
#         95984        0.000000      3.443611        0.990054        1.421712
#         95990        0.000000      3.662987        1.083883        1.286260
#
#                pred_stacked_3  pred_stacked_4
# race_id index
# 13691   95988        0.364451             0.0
#         95986        0.342049             0.0
#         95982        0.312789             0.0
#         95989        1.060258             0.0
#         95985        1.113627             0.0
#         95981        0.573266             0.0
#         95983        0.768771             0.0
#         95987        1.066348             0.0
#         95984        1.031844             0.0
#         95990        1.292844             0.0

# %%
fi = pd.Series(reg2.feature_importances_, index=stacked_features+dummies['sub_category'])
print(fi.sort_values(ascending=False))
# Out:
# final_odds_ref               0.080894
# pred_knn_90_1                0.060379
# pred_rf_100_1                0.054625
# pred_knn_30_1                0.054390
# pred_rf_100_1_r              0.049888
# pred_rf_10_1_r               0.049053
# pred_knn_5_1_r               0.035348
# pred_knn_10_1                0.034716
# pred_rf_10_1                 0.032187
# pred_knn_90_1_std            0.023593
# pred_rf_10_1_std             0.022288
# pred_knn_90_1_mean           0.022135
# pred_rf_100_1_std            0.022065
# pred_rf_100_1_mean           0.022040
# race_count_std               0.021742
# final_odds_ref_std           0.021741
# pred_rf_10_1_mean            0.021632
# pred_knn_30_1_mean           0.021569
# final_odds_ref_mean          0.021454
# race_count_mean              0.020483
# pred_knn_30_1_std            0.020159
# pred_knn_10_1_mean           0.019742
# odds_2                       0.019549
# pred_knn_5_1_mean            0.019544
# odds_3                       0.019309
# odds_1                       0.019035
# pred_knn_10_1_std            0.018689
# pred_knn_5_1                 0.018517
# pred_knn_5_1_std             0.017987
# odds_5                       0.017848
# odds_4                       0.017601
# odds_0                       0.016444
# odds_6                       0.015466
# odds_7                       0.013944
# odds_9                       0.013340
# odds_8                       0.013082
# declared_player_count        0.009737
# HANDICAP                     0.002385
# NATIONALE_AUTOSTART          0.002337
# A_RECLAMER                   0.002279
# HANDICAP_CATEGORIE_DIVISE    0.001930
# HANDICAP_DIVISE              0.001643
# AUTOSTART                    0.001510
# COURSE_A_CONDITIONS          0.001504
# HANDICAP_DE_CATEGORIE        0.001428
# INTERNATIONALE_AUTOSTART     0.001374
# EUROPEENNE_AUTOSTART         0.001070
# pred_knn_90_1_r              0.000159
# pred_knn_10_1_r              0.000089
# pred_knn_30_1_r              0.000076
# dtype: float64

# %%
dummies
# Out:
# {'sub_category': ['COURSE_A_CONDITIONS',
#   'HANDICAP',
#   'AUTOSTART',
#   'HANDICAP_DIVISE',
#   'A_RECLAMER',
#   'HANDICAP_CATEGORIE_DIVISE',
#   'INTERNATIONALE_AUTOSTART',
#   'NATIONALE_AUTOSTART',
#   'HANDICAP_DE_CATEGORIE',
#   'EUROPEENNE_AUTOSTART']}

# %%
df['rnd'] = np.random.rand(len(df))

df['strat_1'] = df['pred_stacked']

races = df.sort_values('start_at').groupby('race_id')

strats = ['strat_1']

bets = []

stash = 500

for (id, race) in races:
    
    nums = []
    
    for k, target in enumerate(strats, 1):
        
#        if len(nums) > 0:
#            break

        r = race.sort_values(by=target, ascending=False)
    
        #r = r[r['final_odds_ref']<40.]
        
        odds = r['final_odds_ref'].min()
        nth = len(r[r['final_odds_ref']<odds])+1
    
        N = 10


        for n in range(N):
            
            if len(r) <= N:
                continue

            player = r.iloc[n]
            odds = player['final_odds_ref']
            
            if r['pred_stacked_1'].std() == 0:
                continue

            #if player['sub_category'] != 'COURSE_A_CONDITIONS':
            #    pass

            if player['num'] in nums:
                continue
                
            if player['pred_stacked_1'] <= 0:
                pass
                
            nth = 0 #(r['final_odds_ref']<odds).sum()+1

            if np.isnan(odds) or odds > 20 or odds < 1:
                continue
                
            if race['final_odds_ref'].min() > 0:
                pass
                
            if race['final_odds_ref'].max() > 30:
                pass

            bet = 1
        
            profit = player['winner_dividend']/100.0 * bet - bet

            bets.append( (id, len(nums)+1, race['race_count'].min(), player['sub_category'], player['country'], player[target], nth, player['declared_player_count'], player['start_at'], bet, player['position'], player['final_odds'], player['pred_stacked_1'], race['final_odds_ref'].std(), player['num'], profit) )

            nums.append(player['num'])
            
            if len(nums) >= 3:
                break



bets = pd.DataFrame(bets, columns=['id', 'bn', 'race_count_min', 'cat', 'country', 'target', 'nth', 'n', 'date', 'bet', 'pos', 'odds', 'pred_1', 'num', 'odds_std', 'profit'])


bets.index = bets['date']

bets = bets.sort_index()

bets['bets'] = bets['bet'].cumsum()
bets['stash'] = bets['profit'].cumsum()

# %%
bets_orig = bets.copy()

# %%
bets = bets_orig

# %%
from cataclop.ml.exploration import loss_streak

bets = bets[(bets['profit']>0) | (bets['pos'] != 1)]
#bets = bets[bets['cat'] == 'HANDICAP']

print('from:', bets['date'].min(), 'to:', bets['date'].max())

print('loss streak:', loss_streak(bets))
print('bets:', (bets['bet']>0).sum())
print('bets:', bets['bet'].sum(), '€')
print('profits:', bets['profit'].sum(), '€')
print('returns:', 100. * (bets['profit'].sum() / bets['bet'].sum()), '%')
print('win rate:', 100. * (bets['profit']>0).astype('float').mean(), '%')
# Out:
# from: 2017-01-01 14:27:00 to: 2018-06-05 21:24:00
# loss streak: 82
# bets: 15516
# bets: 15516 €
# profits: -3067.1 €
# returns: -19.767336942510955 %
# win rate: 9.409641660221707 %

# %%
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt

bb = bets.copy()#bets[(bets['nth']>1.) & (bets['cat']=='HANDICAP') & (bets['odds']>10)].copy()
bb = bets[(bets['bn']<=1) & (bets['odds']>1)].copy()

bb['stash'] = bb['profit'].cumsum()
bb['bets'] = bb['bet'].cumsum()

bb['stash'].plot()
bb['bets'].plot(figsize=(14,8))

# %%
x = bb.index

bets_cat = bb.groupby('cat')

fig, axs = plt.subplots(len(bets_cat), 1, figsize=(14,4*len(bets_cat)))

print( pd.DataFrame([bets_cat['profit'].sum(), bets_cat['profit'].count(), bets_cat['bet'].sum()]) )

i = 0
for cat, b in bets_cat:
    d = b['profit'].cumsum()
    x = d.index
    y = d.values
    axs[i].plot(x, y, label=cat);
    axs[i].legend();
    #(b['profit'].cumsum()).plot(label=cat, subplots=True, ax=axs[i])
    i = i + 1
# Out:
# cat     AMATEURS_AUTOSTART  AMATEURS_EUROPEENNE_AUTOSTART  \
# profit                58.9                           -3.0
# profit                89.0                            3.0
# bet                   89.0                            3.0
#
# cat     AMATEURS_INTERNATIONALE_AUTOSTART  APPRENTIS_LADS_JOCKEYS_AUTOSTART  \
# profit                               -5.0                             -61.6
# profit                                5.0                              81.0
# bet                                   5.0                              81.0
#
# cat     APPRENTIS_LADS_JOCKEYS_A_RECLAMER_AUTOSTART  AUTOSTART  A_RECLAMER  \
# profit                                         13.9     -120.2      -132.9
# profit                                         12.0      898.0       339.0
# bet                                            12.0      898.0       339.0
#
# cat     A_RECLAMER_AUTOSTART  COURSE_A_CONDITIONS  \
# profit                   2.8               -168.5
# profit                  23.0                778.0
# bet                     23.0                778.0
#
# cat     COURSE_A_CONDITION_QUALIF_HP  EUROPEENNE_AUTOSTART  GROUPE_I  \
# profit                         -39.0                 -41.6      34.9
# profit                          39.0                 117.0      51.0
# bet                             39.0                 117.0      51.0
#
# cat     GROUPE_II  GROUPE_III  HANDICAP  HANDICAP_A_RECLAMER  \
# profit      -11.8        12.7    -320.9                 -3.0
# profit       33.0        32.0     810.0                  3.0
# bet          33.0        32.0     810.0                  3.0
#
# cat     HANDICAP_CATEGORIE_DIVISE  HANDICAP_DE_CATEGORIE  HANDICAP_DIVISE  \
# profit                      -96.0                  -29.7           -230.2
# profit                      326.0                  141.0            872.0
# bet                         326.0                  141.0            872.0
#
# cat     INCONNU  INTERNATIONALE_AUTOSTART  NATIONALE_AUTOSTART
# profit      2.3                      15.5                -59.9
# profit     15.0                     118.0                161.0
# bet        15.0                     118.0                161.0

# %%
bb[['id', 'cat', 'country', 'pos', 'odds', 'pred_1', 'profit', 'bet']]
# Out:
#                         id                                          cat  \
# date
# 2017-01-01 14:27:00  12360                                    AUTOSTART
# 2017-01-01 15:32:00  12362                         EUROPEENNE_AUTOSTART
# 2017-01-01 16:10:00  12363                     INTERNATIONALE_AUTOSTART
# 2017-01-02 13:47:00  12384                                    AUTOSTART
# 2017-01-02 14:35:00  12401                              HANDICAP_DIVISE
# 2017-01-02 14:52:00  12386                         EUROPEENNE_AUTOSTART
# 2017-01-02 15:07:00  12402                              HANDICAP_DIVISE
# 2017-01-02 15:22:00  12387                           AMATEURS_AUTOSTART
# 2017-01-02 15:42:00  12403                              HANDICAP_DIVISE
# 2017-01-02 16:12:00  12404                              HANDICAP_DIVISE
# 2017-01-02 17:12:00  12406                                    AUTOSTART
# 2017-01-02 17:42:00  12407                                    AUTOSTART
# 2017-01-02 17:57:00  12414                                     HANDICAP
# 2017-01-02 18:12:00  12408                                    AUTOSTART
# 2017-01-02 18:27:00  12415                                     HANDICAP
# 2017-01-02 20:42:00  12413                                    AUTOSTART
# 2017-01-03 16:12:00  12436                    HANDICAP_CATEGORIE_DIVISE
# 2017-01-03 16:30:00  12428                                    AUTOSTART
# 2017-01-03 16:44:00  12437                    HANDICAP_CATEGORIE_DIVISE
# 2017-01-03 17:17:00  12438                                     HANDICAP
# 2017-01-03 17:48:00  12439                        HANDICAP_DE_CATEGORIE
# 2017-01-03 18:18:00  12440                                   A_RECLAMER
# 2017-01-03 18:50:00  12441                                   A_RECLAMER
# 2017-01-03 19:50:00  12443                                   A_RECLAMER
# 2017-01-04 11:00:00  12461                          COURSE_A_CONDITIONS
# 2017-01-04 11:30:00  12462                          COURSE_A_CONDITIONS
# 2017-01-04 12:15:00  12464                                     HANDICAP
# 2017-01-04 12:45:00  12465                                     HANDICAP
# 2017-01-04 13:00:00  12473                           AMATEURS_AUTOSTART
# 2017-01-04 13:15:00  12466                                     HANDICAP
# ...                    ...                                          ...
# 2018-06-02 18:47:00  19697                                    AUTOSTART
# 2018-06-02 18:50:00  19711                                     HANDICAP
# 2018-06-02 19:02:00  19691                                    AUTOSTART
# 2018-06-02 19:47:00  19699                                    AUTOSTART
# 2018-06-02 21:00:00  19721                                    AUTOSTART
# 2018-06-02 21:34:00  19696                          NATIONALE_AUTOSTART
# 2018-06-03 16:15:00  19726                                     GROUPE_I
# 2018-06-03 16:58:00  19727                                     HANDICAP
# 2018-06-03 18:10:00  19729                        HANDICAP_DE_CATEGORIE
# 2018-06-03 18:43:00  19753                                    AUTOSTART
# 2018-06-03 19:10:00  19754                                    AUTOSTART
# 2018-06-03 19:41:00  19755                                    AUTOSTART
# 2018-06-03 20:10:00  19756                                    AUTOSTART
# 2018-06-04 12:59:00  19774                                    AUTOSTART
# 2018-06-04 14:07:00  19776                                    AUTOSTART
# 2018-06-04 15:11:00  19778                                    AUTOSTART
# 2018-06-04 16:44:00  19781                              HANDICAP_DIVISE
# 2018-06-04 18:15:00  19784                              HANDICAP_DIVISE
# 2018-06-04 18:45:00  19785                                   A_RECLAMER
# 2018-06-05 13:26:00  19806                    HANDICAP_CATEGORIE_DIVISE
# 2018-06-05 14:05:00  19807                    HANDICAP_CATEGORIE_DIVISE
# 2018-06-05 15:20:00  19800                                    AUTOSTART
# 2018-06-05 17:10:00  19813                          COURSE_A_CONDITIONS
# 2018-06-05 17:40:00  19814                          COURSE_A_CONDITIONS
# 2018-06-05 17:55:00  19821                                    AUTOSTART
# 2018-06-05 18:12:00  19815                          COURSE_A_CONDITIONS
# 2018-06-05 18:25:00  19822                                    AUTOSTART
# 2018-06-05 18:40:00  19816                          COURSE_A_CONDITIONS
# 2018-06-05 19:45:00  19818                          COURSE_A_CONDITIONS
# 2018-06-05 21:24:00  19830  APPRENTIS_LADS_JOCKEYS_A_RECLAMER_AUTOSTART
#
#                     country   pos   odds    pred_1  profit  bet
# date
# 2017-01-01 14:27:00     FRA   1.0    4.1  0.952197     3.2    1
# 2017-01-01 15:32:00     FRA   1.0    9.8  1.002698     9.0    1
# 2017-01-01 16:10:00     FRA   4.0   25.0  0.557949    -1.0    1
# 2017-01-02 13:47:00     FRA   9.0   18.6  0.844099    -1.0    1
# 2017-01-02 14:35:00     FRA   8.0   15.9  0.992298    -1.0    1
# 2017-01-02 14:52:00     FRA   8.0   17.6  0.781604    -1.0    1
# 2017-01-02 15:07:00     FRA   1.0    8.6  1.153723     8.7    1
# 2017-01-02 15:22:00     FRA   4.0   17.0  0.961292    -1.0    1
# 2017-01-02 15:42:00     FRA   9.0   22.3  0.834776    -1.0    1
# 2017-01-02 16:12:00     FRA  11.0    5.3  0.995516    -1.0    1
# 2017-01-02 17:12:00     FRA   3.0    7.0  1.257992    -1.0    1
# 2017-01-02 17:42:00     FRA   3.0   18.3  1.046386    -1.0    1
# 2017-01-02 17:57:00     BEL  13.0   13.1  0.780261    -1.0    1
# 2017-01-02 18:12:00     FRA  12.0   22.2  0.916771    -1.0    1
# 2017-01-02 18:27:00     BEL   9.0   12.5  1.071908    -1.0    1
# 2017-01-02 20:42:00     FRA   NaN    3.7  1.031085    -1.0    1
# 2017-01-03 16:12:00     FRA   6.0    9.4  1.175498    -1.0    1
# 2017-01-03 16:30:00     FRA   NaN   18.7  1.033235    -1.0    1
# 2017-01-03 16:44:00     FRA   5.0   11.3  1.150564    -1.0    1
# 2017-01-03 17:17:00     FRA   4.0   10.7  0.726006    -1.0    1
# 2017-01-03 17:48:00     FRA  14.0   10.7  1.288956    -1.0    1
# 2017-01-03 18:18:00     FRA   2.0    7.6  0.632661    -1.0    1
# 2017-01-03 18:50:00     FRA   3.0   13.9  0.772259    -1.0    1
# 2017-01-03 19:50:00     FRA   2.0    8.3  1.038217    -1.0    1
# 2017-01-04 11:00:00     ZAF   6.0    7.2  0.915496    -1.0    1
# 2017-01-04 11:30:00     ZAF   1.0   17.6  0.793052    16.2    1
# 2017-01-04 12:15:00     CHN   1.0   13.7  0.957180    14.2    1
# 2017-01-04 12:45:00     CHN   9.0   45.6  0.769145    -1.0    1
# 2017-01-04 13:00:00     FRA   4.0    8.0  0.894645    -1.0    1
# 2017-01-04 13:15:00     CHN   4.0    9.6  0.888927    -1.0    1
# ...                     ...   ...    ...       ...     ...  ...
# 2018-06-02 18:47:00     FRA   NaN   85.2  1.389655    -1.0    1
# 2018-06-02 18:50:00     GBR  11.0   22.2  0.911864    -1.0    1
# 2018-06-02 19:02:00     FRA   4.0    6.3  0.945404    -1.0    1
# 2018-06-02 19:47:00     FRA   NaN    8.4  0.712785    -1.0    1
# 2018-06-02 21:00:00     FRA   6.0   13.8  0.826194    -1.0    1
# 2018-06-02 21:34:00     FRA   2.0   15.4  0.816042    -1.0    1
# 2018-06-03 16:15:00     FRA   7.0   17.2  0.787338    -1.0    1
# 2018-06-03 16:58:00     FRA  13.0   11.7  1.188652    -1.0    1
# 2018-06-03 18:10:00     FRA  15.0   19.0  1.456410    -1.0    1
# 2018-06-03 18:43:00     IRL   9.0   27.1  0.834632    -1.0    1
# 2018-06-03 19:10:00     IRL   9.0   16.4  0.913853    -1.0    1
# 2018-06-03 19:41:00     IRL   NaN   26.7  0.912471    -1.0    1
# 2018-06-03 20:10:00     IRL   NaN   40.2  0.891442    -1.0    1
# 2018-06-04 12:59:00     FRA   1.0    8.4  0.987608     8.4    1
# 2018-06-04 14:07:00     FRA   2.0   14.5  0.877611    -1.0    1
# 2018-06-04 15:11:00     FRA   8.0   11.3  1.052531    -1.0    1
# 2018-06-04 16:44:00     FRA   8.0    4.7  1.151819    -1.0    1
# 2018-06-04 18:15:00     FRA   7.0   32.1  1.095554    -1.0    1
# 2018-06-04 18:45:00     FRA   4.0   11.5  0.718045    -1.0    1
# 2018-06-05 13:26:00     FRA   2.0   14.8  1.252211    -1.0    1
# 2018-06-05 14:05:00     FRA   5.0    7.9  1.153737    -1.0    1
# 2018-06-05 15:20:00     FRA   6.0   10.5  0.909750    -1.0    1
# 2018-06-05 17:10:00     MAR  14.0   22.1  1.060204    -1.0    1
# 2018-06-05 17:40:00     MAR   6.0   12.5  0.949398    -1.0    1
# 2018-06-05 17:55:00     CHE   6.0    3.6  0.755427    -1.0    1
# 2018-06-05 18:12:00     MAR   4.0   24.3  0.699359    -1.0    1
# 2018-06-05 18:25:00     CHE   3.0   10.9  0.721947    -1.0    1
# 2018-06-05 18:40:00     MAR   7.0  149.4  1.176432    -1.0    1
# 2018-06-05 19:45:00     MAR   5.0    3.3  1.056331    -1.0    1
# 2018-06-05 21:24:00     FRA   3.0   12.5  0.741886    -1.0    1
#
# [5200 rows x 8 columns]

# %%
#bets['nth_r'] = bets['nth'] / bets['n']
bets[bets['profit']>0].describe()
# Out:
#                  id           bn  race_count_min       target          nth  \
# count   2304.000000  2304.000000     2304.000000  2304.000000  2304.000000
# mean   10400.527778     1.884983        8.486979     0.952093     2.406250
# std     5548.495336     0.821054       11.115968     0.227221     1.912292
# min        4.000000     1.000000        0.000000     0.374017     1.000000
# 25%     5745.500000     1.000000        1.000000     0.783884     1.000000
# 50%    10879.000000     2.000000        5.000000     0.931417     2.000000
# 75%    14989.250000     3.000000       11.000000     1.091350     3.000000
# max    19830.000000     3.000000       72.000000     1.909895    12.000000
#
#                  n     bet     pos         odds       pred_1          num  \
# count  2304.000000  2304.0  2304.0  2304.000000  2304.000000  2304.000000
# mean     13.786458     1.0     1.0     5.716059     0.280421    44.188585
# std       1.990527     0.0     0.0     4.559000     0.064930   313.987285
# min      11.000000     1.0     1.0     1.100000     0.065937     2.973063
# 25%      12.000000     1.0     1.0     2.900000     0.237441    10.943425
# 50%      14.000000     1.0     1.0     4.300000     0.277880    16.207843
# 75%      16.000000     1.0     1.0     7.000000     0.319584    24.991584
# max      24.000000     1.0     1.0    52.000000     0.563067  5218.118388
#
#           odds_std       profit          bets        stash        nth_r
# count  2304.000000  2304.000000   2304.000000  2304.000000  2304.000000
# mean      6.039497     4.882465   7809.062500 -1096.700130     0.176692
# std       3.791196     4.922990   4517.339027   601.583591     0.140622
# min       1.000000     0.100000      1.000000 -1960.800000     0.050000
# 25%       3.000000     1.800000   3849.500000 -1717.725000     0.076923
# 50%       6.000000     3.500000   7883.000000 -1172.350000     0.125000
# 75%       9.000000     6.225000  11792.750000  -547.550000     0.230769
# max      20.000000    61.400000  15514.000000    21.300000     1.000000

# %%
bets[bets['profit']<0].describe()
# Out:
#                  id            bn  race_count_min        target           nth  \
# count  13206.000000  13206.000000    13206.000000  13206.000000  13206.000000
# mean   10226.815917      2.015145        8.291837      0.917341      3.587687
# std     5555.535253      0.813879       10.232641      0.214493      2.407422
# min        3.000000      1.000000        0.000000      0.133966      1.000000
# 25%     5546.500000      1.000000        2.000000      0.765970      2.000000
# 50%    10583.000000      2.000000        5.000000      0.892076      3.000000
# 75%    14664.000000      3.000000       11.000000      1.040976      5.000000
# max    19830.000000      3.000000       72.000000      2.492798     15.000000
#
#                   n      bet           pos          odds        pred_1  \
# count  13206.000000  13206.0  11925.000000  13203.000000  13206.000000
# mean      13.999470      1.0      6.050314     10.108127      0.251458
# std        2.058644      0.0      3.388911      8.245871      0.060411
# min       11.000000      1.0      2.000000      1.200000     -0.054950
# 25%       12.000000      1.0      3.000000      5.000000      0.211239
# 50%       14.000000      1.0      5.000000      7.700000      0.250220
# 75%       16.000000      1.0      8.000000     12.500000      0.288974
# max       24.000000      1.0     19.000000    194.600000      0.598651
#
#                 num      odds_std   profit          bets         stash  \
# count  13206.000000  13206.000000  13206.0  13206.000000  13206.000000
# mean      63.535556      6.604044     -1.0   7749.429123  -1092.651136
# std      419.509763      3.996027      0.0   4473.322069    595.179213
# min        2.343835      1.000000     -1.0      2.000000  -1965.600000
# 25%        9.946572      3.000000     -1.0   3884.250000  -1688.375000
# 50%       14.428448      6.000000     -1.0   7739.500000  -1169.850000
# 75%       21.992948     10.000000     -1.0  11609.750000   -558.600000
# max     5218.474541     24.000000     -1.0  15516.000000     20.300000
#
#               nth_r
# count  13206.000000
# mean       0.259708
# std        0.174501
# min        0.041667
# 25%        0.125000
# 50%        0.214286
# 75%        0.363636
# max        1.000000

# %%
bets[bets['odds']>]['profit'].describe()
# Out:
# count    350.000000
# mean       0.230286
# std        5.265838
# min       -1.000000
# 25%       -1.000000
# 50%       -1.000000
# 75%       -1.000000
# max       35.200000
# Name: profit, dtype: float64

# %%
bets.plot.scatter(x='profit', y='pred_1', figsize=(14,8))

# %%
bets.describe()
# Out:
#                  id            bn  race_count_min        target           nth  \
# count  15510.000000  15510.000000    15510.000000  15510.000000  15510.000000
# mean   10252.620696      1.995809        8.320825      0.922503      3.412186
# std     5554.654878      0.816236       10.368476      0.216776      2.377869
# min        3.000000      1.000000        0.000000      0.133966      1.000000
# 25%     5639.000000      1.000000        1.000000      0.769245      1.000000
# 50%    10638.000000      2.000000        5.000000      0.897494      3.000000
# 75%    14722.000000      3.000000       11.000000      1.048896      5.000000
# max    19830.000000      3.000000       72.000000      2.492798     15.000000
#
#                   n      bet           pos          odds        pred_1  \
# count  15510.000000  15510.0  14229.000000  15507.000000  15510.000000
# mean      13.967827      1.0      5.232553      9.455562      0.255761
# std        2.050006      0.0      3.617515      7.963584      0.061964
# min       11.000000      1.0      1.000000      1.100000     -0.054950
# 25%       12.000000      1.0      2.000000      4.500000      0.214948
# 50%       14.000000      1.0      4.000000      7.200000      0.253786
# 75%       16.000000      1.0      8.000000     11.700000      0.293663
# max       24.000000      1.0     19.000000    194.600000      0.598651
#
#                 num      odds_std        profit          bets         stash  \
# count  15510.000000  15510.000000  15510.000000  15510.000000  15510.000000
# mean      60.661577      6.520181     -0.126164   7758.287621  -1093.252611
# std      405.624098      3.971229      2.824162   4479.791882    596.117159
# min        2.343835      1.000000     -1.000000      1.000000  -1965.600000
# 25%       10.055516      3.000000     -1.000000   3878.250000  -1695.650000
# 50%       14.661664      6.000000     -1.000000   7757.500000  -1170.300000
# 75%       22.398816      9.000000     -1.000000  11637.750000   -557.250000
# max     5218.474541     24.000000     61.400000  15516.000000     21.300000
#
#               nth_r
# count  15510.000000
# mean       0.247376
# std        0.172438
# min        0.041667
# 25%        0.090909
# 50%        0.200000
# 75%        0.333333
# max        1.000000

# %%
len(bets)
# Out:
# 15510
