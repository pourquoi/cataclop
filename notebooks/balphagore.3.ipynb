# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
pd.set_option('display.max_rows', 500)

from cataclop.ml.pipeline.balphagore import Balphagore
# Out:
# 2021-11-01 02:32:47.392351: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-01 02:32:47.392629: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def reco_mysql():
    from django.db import connections, connection
    for conn in connections.all():
        conn.close_if_unusable_or_obsolete()

# %%
balphagore = Balphagore()
balphagore.load_dataset(filters={'start_at__date__gte':'2019-01-01', 'start_at__date__lte':'2019-12-31', 'sub_category__in': ['AUTOSTART', 'NATIONALE']})
# Out:
# 2020 races

# %%
balphagore.df['target'] = balphagore.df['placed_dividend']/100
balphagore.TARGET = 'target'

# %%
balphagore.train()
# Out:
# 20350 train samples, 4981 validation samples
# Epoch 1/5
# 318/318 [==============================] - 2s 4ms/step - loss: 4.4359
# Epoch 2/5
# 318/318 [==============================] - 1s 5ms/step - loss: 3.4937
# Epoch 3/5
# 318/318 [==============================] - 1s 4ms/step - loss: 4.1939
# Epoch 4/5
# 318/318 [==============================] - 2s 5ms/step - loss: 3.9248
# Epoch 5/5
# 318/318 [==============================] - 2s 5ms/step - loss: 4.0048
# 318/318 [==============================] - 1s 3ms/step
# Epoch 1/5
# 318/318 [==============================] - 2s 4ms/step - loss: 4.0756
# Epoch 2/5
# 318/318 [==============================] - 2s 5ms/step - loss: 3.9693
# Epoch 3/5
# 318/318 [==============================] - 2s 5ms/step - loss: 3.6824
# Epoch 4/5
# 318/318 [==============================] - 1s 4ms/step - loss: 3.8366
# Epoch 5/5
# 318/318 [==============================] - 1s 4ms/step - loss: 3.9150
# 318/318 [==============================] - 1s 3ms/step

# %%
balphagore.debug_race(balphagore.df_train)
# Out:
#                position sub_category  num                     music  \
# race_id
# 78207   2007        1.0    AUTOSTART   10      Da4a0a(18)1a1a0a5a8a
#         2006        NaN    AUTOSTART    9  3a2a(18)6a0a8a0a6a(17)Da
#         2011       11.0    AUTOSTART   14    7a6a(18)8a4a4a4a5aDa2a
#         2009        8.0    AUTOSTART   12    0a2a7a5a(18)4a2aDmDa9a
#         2008        2.0    AUTOSTART   11    Da3a3a1a1aDmDm(18)1a4a
#         1998        6.0    AUTOSTART    1    9a0a(18)9aDa7a4a3aDa0a
#         1999       10.0    AUTOSTART    2    Da0a0a(18)2a1aDa6a0aDa
#         2010        9.0    AUTOSTART   13    4aDa7a5a0a8aDa(18)0a0a
#         2001        4.0    AUTOSTART    4    (18)3a5a2a0a5a3a7a3aDa
#         2002        3.0    AUTOSTART    5    6a4aDa7a2aDa1a(18)2a2a
#         2003        7.0    AUTOSTART    6    3a9a5a4a0a0a(18)6a2a0a
#         2004        5.0    AUTOSTART    7    1m2m7a(18)5m1mDaDa2aDa
#         2005        NaN    AUTOSTART    8    Da0aDa1a(18)5aDm6a3a0m
#         2000        NaN    AUTOSTART    3    3m0aDaDa9a0a(18)8a2aDa
# 78632   2847        2.0    AUTOSTART    2              2a3a4a1aDa0a
#         2856        5.0    AUTOSTART   11          2a1a1a6a(18)1a1a
#         2855        9.0    AUTOSTART   10              0a0aDa0a3a0a
#         2854        6.0    AUTOSTART    9              0aDa0a6a0a6a
#         2852        4.0    AUTOSTART    7              2a3aDa2a2a1a
#         2851        1.0    AUTOSTART    6          1a1a3a7a(18)3a3a
#         2850        3.0    AUTOSTART    5              4a3a4a2a2a3a
#         2849        NaN    AUTOSTART    4              5a0a5a7a4a0a
#         2848        NaN    AUTOSTART    3              4a7a2a0a0a3a
#         2846        8.0    AUTOSTART    1              Ra3a1a2a6a1a
#         2853        7.0    AUTOSTART    8              Da6a6a0a6a0a
# 78904   3295        9.0    AUTOSTART    2              4a6a2a0a2a0a
#         3297        1.0    AUTOSTART    4              1a0a5a3a2aDa
#         3298        6.0    AUTOSTART    5              4a1a7a0a2a1a
#         3299        2.0    AUTOSTART    6              Da1a2a4aDa3a
#         3300        4.0    AUTOSTART    7              4a3a0a1a3a0a
#         3301        8.0    AUTOSTART    8              6a0a7a0aRa7a
#         3303        NaN    AUTOSTART   10              3a5a3a6a7a0a
#         3302        3.0    AUTOSTART    9              1a2a4a4a7a0a
#         3294        7.0    AUTOSTART    1          0a5a2a4a0a(18)0a
#         3296        5.0    AUTOSTART    3              Da2a4a1aDm1a
# 79662   4811        NaN    AUTOSTART   11    Da1a2a3a1aDaDa(18)Da4a
#         4810        3.0    AUTOSTART   10        2a6aDa1a9a8a0a4a1a
#         4808       10.0    AUTOSTART    8    Da1aDa3a4a(18)6a3aDa6a
#         4807        1.0    AUTOSTART    7    2a8a9a0a(18)2a3a1a2a1a
#         4806        8.0    AUTOSTART    6    0a6a0a0a(18)4a2a1a5a0a
#         4805        6.0    AUTOSTART    5    5a6a8a9a6a(18)4a6a0aDa
#         4804        5.0    AUTOSTART    4    0a6a2a1a9a7a(18)1aDa1a
#         4803        4.0    AUTOSTART    3    4a2a6a1a(18)0a1a4a0a0a
#         4802        2.0    AUTOSTART    2    2a6a6a0a(18)7a8a6a7a2a
#         4801        7.0    AUTOSTART    1    1aDa1a0a1a(18)2a3a2aDa
#         4809        9.0    AUTOSTART    9    0mDmDm(18)Dm6mDmDm5mDm
# 79915   5362        NaN    NATIONALE   10                    Da3a1a
#         5363        6.0    NATIONALE   11            2a3a6a0a4aDa6a
#         5354        5.0    NATIONALE    2              8a6a4a(18)2a
#         5353        NaN    NATIONALE    1                        Da
#         5364        NaN    NATIONALE   12                (18)1a5aDa
#         5365        1.0    NATIONALE   13                  1aDa3a7a
#         5361        NaN    NATIONALE    9          1a7aDa4a(18)5a8a
#         5360        NaN    NATIONALE    8        6a3a3a7a3a0a(18)6a
#         5366        7.0    NATIONALE   14    8a8a2aDa3aDa6a4a(18)7a
#         5358        8.0    NATIONALE    6      8a7aDa9a9a6aDaDa0aDa
#         5357        2.0    NATIONALE    5                        1a
#         5356        NaN    NATIONALE    4      6aDa4aDaDaDa6aDaDa4a
#         5355        3.0    NATIONALE    3                        1a
#         5359        4.0    NATIONALE    7            Da3a2a4a(18)Da
# 83543   13153       8.0    NATIONALE    8      7a6a4a1a6aDa2a6a4a5a
#         13157       NaN    NATIONALE   12      8a4aDa3a9a1aDa2aDa6a
#         16886       5.0    AUTOSTART    4                5a2a9a1a2a
#         16885       3.0    AUTOSTART    3      Da5a4aDa7m1a2aDmDaDa
#         16884       NaN    AUTOSTART    2                1aDa1a5a4a
#         16894       6.0    AUTOSTART   12                  Aa2a6a1a
#         16896       NaN    AUTOSTART   14          DaDaDa2a6a2a4aDa
#         16883       4.0    AUTOSTART    1        4a5a4a3aDa3a7a1a5a
#         16897       7.0    AUTOSTART   15    0a5a3aDaDa(18)0a5a4a4a
# 87454   20263       4.0    AUTOSTART   13                        5a
#         20261       NaN    AUTOSTART   11                        Da
#         20260       NaN    AUTOSTART   10                9aDaDa8a6a
#         20259       NaN    AUTOSTART    9                        Da
#         20258       8.0    AUTOSTART    8                      2aDa
#         20257       2.0    AUTOSTART    7                  4aDaDa3a
#         20256       7.0    AUTOSTART    6                      1a4a
#         20255       6.0    AUTOSTART    5              2aDaDa5aDaDa
#         20254       9.0    AUTOSTART    4                        4a
#         20253       1.0    AUTOSTART    3                    3a2a7a
#         20252       NaN    AUTOSTART    2                  8a6aDa4a
#         20251       5.0    AUTOSTART    1                  3a5a7a7a
#         20262       3.0    AUTOSTART   12                    7a0a8a
#
#                final_odds  final_odds_ref      pred
# race_id
# 78207   2007          5.2             8.8  0.691999
#         2006         18.0            14.0  0.706446
#         2011         82.0           113.0  0.695157
#         2009         21.0            16.0  0.686400
#         2008          5.9             8.0  0.688400
#         1998         18.0            11.0  0.715736
#         1999         22.0            46.0  0.724065
#         2010         12.0             4.0  0.707690
#         2001         13.0            14.0  0.705948
#         2002          6.5             7.8  0.739046
#         2003          6.8             9.1  0.718926
#         2004          8.4            11.0  0.723492
#         2005         71.0            83.0  0.690187
#         2000         93.0            33.0  0.710858
# 78632   2847          6.4             7.6  0.809902
#         2856          6.6             6.7  0.758425
#         2855        136.0           174.0  0.806388
#         2854         57.0           116.0  0.808590
#         2852          4.7            12.0  0.813616
#         2851          2.1             1.7  0.820012
#         2850         31.0            23.0  0.801141
#         2849         50.0            58.0  0.803767
#         2848        110.0            65.0  0.769280
#         2846         20.0            10.0  0.801921
#         2853         30.0            34.0  0.792678
# 78904   3295          3.6             3.2  0.745619
#         3297         10.0             9.8  0.754840
#         3298         19.0            15.0  0.744659
#         3299          4.0             4.2  0.741098
#         3300         28.0            17.0  0.745221
#         3301        129.0            77.0  0.744883
#         3303         32.0            30.0  0.751591
#         3302          5.8             4.5  0.745357
#         3294         62.0            44.0  0.747924
#         3296          4.2            10.0  0.748833
# 79662   4811          1.8             2.6  0.665084
#         4810         16.0            15.0  0.722225
#         4808         76.0            38.0  0.714187
#         4807          8.0             7.3  0.726440
#         4806         57.0            30.0  0.726251
#         4805         27.0            14.0  0.723184
#         4804         61.0            31.0  0.729872
#         4803          6.1             5.4  0.699856
#         4802         13.0             8.9  0.738739
#         4801          8.6             8.8  0.722905
#         4809        214.0            83.0  0.732539
# 79915   5362         11.0             7.8  0.738083
#         5363         11.0             9.8  0.785685
#         5354         15.0            17.0  0.775308
#         5353        100.0            52.0  0.706278
#         5364         11.0            10.0  0.774949

# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1616/1616 [04:22<00:00,  6.16it/s]

# %%
for strat in range(6):
    print(strat+1)
    print(balphagore.bets[balphagore.bets['strategy']==strat+1].filter(regex='^top', axis=1).mean())
# Out:
# 1
# top1_correct             0.129950
# top1_in_3_correct        0.331064
# top2_correct             0.017327
# top2_correct_disorder    0.034035
# top3_correct             0.002475
# top3_correct_disorder    0.015470
# top4_correct             0.001238
# top4_correct_disorder    0.011757
# top2_in_4_correct        0.163985
# dtype: float64
# 2
# top1_correct             0.100866
# top1_in_3_correct        0.249381
# top2_correct             0.008045
# top2_correct_disorder    0.014233
# top3_correct             0.001238
# top3_correct_disorder    0.004332
# top4_correct             0.000000
# top4_correct_disorder    0.005569
# top2_in_4_correct        0.118812
# dtype: float64
# 3
# top1_correct             0.086015
# top1_in_3_correct        0.265470
# top2_correct             0.010520
# top2_correct_disorder    0.024134
# top3_correct             0.000000
# top3_correct_disorder    0.015470
# top4_correct             0.000000
# top4_correct_disorder    0.003713
# top2_in_4_correct        0.134282
# dtype: float64
# 4
# top1_correct             0.129950
# top1_in_3_correct        0.331064
# top2_correct             0.013614
# top2_correct_disorder    0.024134
# top3_correct             0.001856
# top3_correct_disorder    0.009901
# top4_correct             0.000000
# top4_correct_disorder    0.005569
# top2_in_4_correct        0.118812
# dtype: float64
# 5
# top1_correct             0.351485
# top1_in_3_correct        0.597153
# top2_correct             0.099629
# top2_correct_disorder    0.157178
# top3_correct             0.023515
# top3_correct_disorder    0.086634
# top4_correct             0.004332
# top4_correct_disorder    0.050743
# top2_in_4_correct        0.446782
# dtype: float64
# 6
# top1_correct             0.351485
# top1_in_3_correct        0.597153
# top2_correct             0.099629
# top2_correct_disorder    0.157178
# top3_correct             0.008045
# top3_correct_disorder    0.105817
# top4_correct             0.001238
# top4_correct_disorder    0.071782
# top2_in_4_correct        0.402847
# dtype: float64

# %%
reco_mysql()
balphagore.compute_profit()
# Out:
#   0%|▏                                                                                                                                                      | 11/11312 [00:00<11:51, 15.89it/s]/opt/pysetup/.venv/lib/python3.7/site-packages/numpy/core/numeric.py:2378: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11312/11312 [03:01<00:00, 62.33it/s]

# %%
print(balphagore.bets['race_id'].nunique())
b = balphagore.bets
b = b[b['pred']>0]
for strat in range(7):
    print(strat+1)
    print(b[b['strategy']==strat+1].filter(regex='^profit_', axis=1).mean())
# Out:
# 1616
# 1
# profit_win                     -0.151671
# profit_placed                  -0.084530
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.418564
# profit_top3_correct            -0.035272
# profit_top3_correct_disorder   -0.346844
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder    1.050990
# profit_top2_in_4_correct       -0.229332
# dtype: float64
# 2
# profit_win                     -0.198144
# profit_placed                  -0.298948
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.545730
# profit_top3_correct            -0.035272
# profit_top3_correct_disorder   -0.392636
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder   -0.376609
# profit_top2_in_4_correct       -0.513181
# dtype: float64
# 3
# profit_win                     -0.032178
# profit_placed                  -0.171040
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.260891
# profit_top3_correct            -0.035272
# profit_top3_correct_disorder   -0.298948
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder   -0.383045
# profit_top2_in_4_correct       -0.289295
# dtype: float64
# 4
# profit_win                     -0.151671
# profit_placed                  -0.084530
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.260891
# profit_top3_correct            -0.014604
# profit_top3_correct_disorder   -0.709530
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder   -0.376609
# profit_top2_in_4_correct       -0.289295
# dtype: float64
# 5
# profit_win                     -0.146782
# profit_placed                  -0.123082
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.180446
# profit_top3_correct            -0.019245
# profit_top3_correct_disorder   -0.259097
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder   -0.265780
# profit_top2_in_4_correct       -0.164295
# dtype: float64
# 6
# profit_win                     -0.146782
# profit_placed                  -0.123082
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.180446
# profit_top3_correct            -0.029146
# profit_top3_correct_disorder    1.060953
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder    0.475928
# profit_top2_in_4_correct       -0.164295
# dtype: float64
# 7
# profit_win                     -0.146782
# profit_placed                  -0.123082
# profit_top2_correct             0.000000
# profit_top2_correct_disorder    0.512252
# profit_top3_correct            -0.019988
# profit_top3_correct_disorder    1.151300
# profit_top4_correct            -0.008045
# profit_top4_correct_disorder    0.475928
# profit_top2_in_4_correct       -0.230260
# dtype: float64

# %%
profit_cols = [col for col in balphagore.bets.columns if col.startswith('profit_')]

# %%
from matplotlib import pyplot as plt
for subcat in balphagore.bets.sub_category.value_counts().index[:5]:
    print(subcat)
    b = balphagore.bets
    b = b[(b['sub_category']==subcat) & (b['pred'] > 0)].copy()
    b.reset_index(inplace=True, drop=True)
    for strat in range(7):
        print(strat+1)
        for col in profit_cols:
            b[b['strategy']==strat+1][col].cumsum().plot(title=subcat, legend=True, figsize=(14,4))
        plt.show()
# Out:
# AUTOSTART
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# NATIONALE
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
subcat = 'AUTOSTART'
col = 'profit_top3_correct_disorder'
strat = 7

b = balphagore.bets
b = b[(b['sub_category']==subcat) & (b['final_odds'] < 30) & ((b['strategy']==strat+1)) & (b['declared_player_count']<14)].copy()
b.reset_index(inplace=True, drop=True)
b[col].cumsum().plot()
b[profit_cols].mean()
# Out:
# profit_win                     -0.306971
# profit_placed                  -0.022596
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.104567
# profit_top3_correct            -0.069471
# profit_top3_correct_disorder    2.364904
# profit_top4_correct             0.000000
# profit_top4_correct_disorder    0.000000
# profit_top2_in_4_correct       -0.080048
# dtype: float64

# %%
subcat = 'AUTOSTART'
col = 'profit_top3_correct_disorder'
strat = 7

b = balphagore.bets
b = b[(b['sub_category']==subcat) & (b['b_odds_mean3'] < 20) & (b['b_odds_mean3'] > b['b_odds_mean2']) & ((b['strategy']==strat+1)) & (b['declared_player_count']<20)].copy()
b.reset_index(inplace=True, drop=True)
b[col].cumsum().plot()
b[profit_cols].mean()
# Out:
# profit_win                     -0.020000
# profit_placed                  -0.030588
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.031176
# profit_top3_correct             0.018235
# profit_top3_correct_disorder    5.084706
# profit_top4_correct            -0.005882
# profit_top4_correct_disorder   -0.182353
# profit_top2_in_4_correct        0.022353
# dtype: float64

# %%
subcat = 'HANDICAP'
col = 'profit_win'
strat = 7

b = balphagore.bets
b = b[(b['sub_category']==subcat) & (b['b_odds_mean3'] > 20) & ((b['strategy']==strat+1))].copy()
b.reset_index(inplace=True, drop=True)
b[col].cumsum().plot()
b[profit_cols].mean()
# Out:
# profit_win                      0.221811
# profit_placed                   0.233333
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -1.000000
# profit_top3_correct             0.000000
# profit_top3_correct_disorder   -0.954733
# profit_top4_correct            -0.045267
# profit_top4_correct_disorder   -0.337449
# profit_top2_in_4_correct       -0.399177
# dtype: float64

# %%
cols = ['profit_top3_correct_disorder']
b[b['profit_top3_correct_disorder']>0][['race_id', 'start_at', 'b_odds_sum', 'b_odds_1', 'b_odds_2', 'b_odds_3', 'odds_1', 'odds_2', 'odds_3', 'combo', 'combo_real', 'odds'] + cols]
# Out:
#      race_id            start_at  b_odds_sum  b_odds_1  b_odds_2  b_odds_3  \
# 42     78561 2019-05-05 11:10:00   10.066667       5.5      19.0       5.7
# 61     79311 2019-05-25 15:54:00   13.966667      32.0       5.3       4.6
# 162    82295 2019-08-09 19:50:00   12.666667      14.0      11.0      13.0
# 173    82613 2019-08-17 22:25:00    8.033333       3.9       8.2      12.0
# 184    82888 2019-08-25 11:40:00    5.000000       2.6       6.4       6.0
# 243    84540 2019-10-10 17:02:00   10.833333      14.0       7.5      11.0
# 282    85685 2019-11-10 11:05:00   11.333333      17.0      12.0       5.0
# 310    86530 2019-12-03 21:30:00    7.666667       6.5       4.5      12.0
#
#      odds_1  odds_2  odds_3              combo  combo_real  \
# 42      5.5     5.7     6.9    [3, 5, 7, 9, 1]   [7, 5, 3]
# 61      4.6     5.3     7.2   [10, 5, 7, 2, 1]  [7, 5, 10]
# 162     5.1     7.6     8.3  [5, 11, 2, 10, 8]  [5, 11, 2]
# 173     4.7     7.3     8.2   [3, 8, 2, 9, 11]   [3, 8, 2]
# 184     6.0     6.4     6.5    [4, 6, 3, 7, 2]   [6, 3, 4]
# 243     7.5     8.6    11.0   [12, 2, 4, 8, 1]  [4, 12, 2]
# 282     5.0    12.0    13.0    [1, 4, 7, 8, 5]   [1, 7, 4]
# 310     4.5     4.5     6.5    [2, 6, 3, 7, 8]   [2, 3, 6]
#
#                               odds  profit_top3_correct_disorder
# 42     [5.5, 19.0, 5.7, 32.0, 6.9]                         158.4
# 61      [32.0, 5.3, 4.6, 7.2, 8.8]                         151.2
# 162   [14.0, 11.0, 13.0, 8.8, 7.6]                         192.3
# 173    [3.9, 8.2, 12.0, 8.8, 16.0]                         548.3
# 184    [2.6, 6.4, 6.0, 29.0, 10.0]                          39.8
# 243  [14.0, 7.5, 11.0, 70.0, 47.0]                         176.6
# 282  [17.0, 12.0, 5.0, 21.0, 13.0]                          45.8
# 310     [6.5, 4.5, 12.0, 4.5, 2.8]                          61.4

# %%
np.std([5.5,19.0,5.7])
# Out:
# 6.317348248188387

# %%
b[profit_cols].mean()
# Out:
# profit_win                     -0.240000
# profit_placed                   0.057846
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.329231
# profit_top3_correct            -0.085846
# profit_top3_correct_disorder    3.377846
# profit_top4_correct             0.000000
# profit_top4_correct_disorder    0.000000
# profit_top2_in_4_correct       -0.065846
# dtype: float64

# %%
b['b_odds_1']
# Out:
# 0      15.0
# 1      17.5
# 2      12.2
# 3      14.8
# 4      23.8
#        ...
# 645    23.0
# 646    22.0
# 647    17.0
# 648    42.0
# 649     9.4
# Name: b_odds_1, Length: 650, dtype: float64

# %%
b['odds_1']
# Out:
# 0      5.8
# 1      5.8
# 2      5.9
# 3      6.8
# 4      4.4
#       ...
# 645    3.6
# 646    8.3
# 647    3.6
# 648    4.2
# 649    5.8
# Name: odds_1, Length: 650, dtype: float64

# %%
balphagore.save_model()

# %%
reco_mysql()
balphagore2 = Balphagore()
balphagore2.load_dataset(filters={'start_at__date__gte':'2021-09-01', 'start_at__date__lte':'2021-10-01'})
# Out:
# 1281 races

# %%
balphagore2.load_model()

# %%
balphagore2.models = balphagore.models

# %%
balphagore2.predict(balphagore2.df)
# Out:
# 454/454 [==============================] - 2s 4ms/step

# %%
balphagore2.debug_race()
# Out:
#                  position         sub_category  num                   music  \
# race_id id
# 111020  1348111       2.0            NATIONALE    8  0a0aDaDa(20)3a4aDa0a2a
#         1348107       NaN            NATIONALE    4    Da2aDa2a2a6a5aDa5a9a
#         1348106      10.0            NATIONALE    3      9a7a1a1a2a8aRa7aDa
#         1348105       6.0            NATIONALE    2    6a6a0aDaDa2a1a2aDa4a
#         1348104      12.0            NATIONALE    1    DaDa0a1a3aDa5a4a2aDa
#         1348110       8.0            NATIONALE    7          Da4a2a3a2a2a1a
#         1348112      11.0            NATIONALE    9            3a1aDa1a2a2a
#         1348113       9.0            NATIONALE   10        6a2aDa7a1a2a4a1a
#         1348114       5.0            NATIONALE   11    1a4a7a3a7a0a4a8a5a4a
#         1348115       NaN            NATIONALE   12  3a3a1a1a2a3a3a(20)3a9a
#         1348116       NaN            NATIONALE   13    Da4a1a6aDa3aDa7a2a7a
#         1348117       NaN            NATIONALE   14  6m6m2m(20)1mDm4m3m5m6a
#         1348118       4.0            NATIONALE   15    DaDaDa3a6a4a5aDa2a6a
#         1348119       1.0            NATIONALE   16    0a2a2a1a4a4a4a3a4a8a
#         1348108       7.0            NATIONALE    5  5a1aDaDa9a2a8a5a(20)9a
#         1348109       3.0            NATIONALE    6    3a0a5aDa0a3aDa3a4a3a
# 111504  1353521      14.0              INCONNU    3  0aDa6a0a(20)5a5a7a3a8a
#         1353520       1.0              INCONNU    2  5a7a0a3a2a1a5a2a(20)9a
#         1353519       NaN              INCONNU    1    1a1a1a9a9aDaDaDaDa6a
#         1353535       2.0              INCONNU   17  6a1a2a1aDa2a1a2a(20)Da
#         1353536      10.0              INCONNU   18  2a9a0a5a3a6a0a8a(20)6a
#         1353533       4.0              INCONNU   15    4a2a4mDa1a5a2a5a3a4a
#         1360105       NaN            NATIONALE    1  DaDmDaDaDa9a(20)DaDaDa
#         1360119       5.0            NATIONALE   15    8a4aDa3a6a5aDa3aDa2a
# 112121  1360569       NaN  COURSE_A_CONDITIONS   11                  Inédit
#         1360568       NaN  COURSE_A_CONDITIONS   10                  7p8p0p
#         1360567       3.0  COURSE_A_CONDITIONS    9                  Inédit
#         1360566       6.0  COURSE_A_CONDITIONS    8                  Inédit
#         1360565       1.0  COURSE_A_CONDITIONS    7                    5p9p
#         1360564       2.0  COURSE_A_CONDITIONS    6                  Inédit
#         1360563       NaN  COURSE_A_CONDITIONS    5                      0p
#         1360562       NaN  COURSE_A_CONDITIONS    4                  Inédit
#         1360561       NaN  COURSE_A_CONDITIONS    3                    1p3p
#         1360560       5.0  COURSE_A_CONDITIONS    2                      0p
#         1360570       8.0  COURSE_A_CONDITIONS   12                      9p
#         1360559       4.0  COURSE_A_CONDITIONS    1                  Inédit
#         1360572       NaN  COURSE_A_CONDITIONS   14                  Inédit
#         1360571       7.0  COURSE_A_CONDITIONS   13                  Inédit
# 112147  1360869       8.0            AUTOSTART    3            6a5a7a3a5a4a
#         1360867      10.0            AUTOSTART    1            0a6a7a5a6a0a
#         1360868       7.0            AUTOSTART    2            7a1a3a4a3a1a
#         1360877       6.0            AUTOSTART   11            Da6a2a2a2a1a
#         1360876       1.0            AUTOSTART   10            2a4a3a3a2a1a
#         1360875       4.0            AUTOSTART    9            Da3a1a1a1a3a
#         1360874       9.0            AUTOSTART    8        Da(20)0aDaDaDaDa
#         1360873       2.0            AUTOSTART    7            1a3a1a1aRa1a
#         1360872       NaN            AUTOSTART    6            0aDa7aDa0aDa
#         1360871       5.0            AUTOSTART    5            7a7a1a1a2aDa
#         1360870       3.0            AUTOSTART    4            3a0a1a5a6a1a
#
#                  final_odds  final_odds_ref      pred
# race_id id
# 111020  1348111       18.00             9.4  1.978085
#         1348107       27.00            35.0  1.940193
#         1348106       75.00            42.0  1.880764
#         1348105      101.00            60.0  1.952053
#         1348104      131.00            47.0  2.133107
#         1348110       22.00            22.0  1.825516
#         1348112        3.50             3.3  1.536253
#         1348113       35.00            27.0  1.636796
#         1348114       24.00            19.0  1.645556
#         1348115        3.00             4.3  1.446573
#         1348116        9.40             8.2  1.841344
#         1348117      183.00            86.0  1.769397
#         1348118       50.00            25.0  1.946453
#         1348119        8.50            24.0  1.743515
#         1348108       45.00            36.0  1.770581
#         1348109       20.00            16.0  1.944754
# 111504  1353521      328.00           164.0  2.272279
#         1353520        9.00            10.0  1.841630
#         1353519        7.20             9.3  1.651673
#         1353535        5.20             4.2  1.747966
#         1353536       18.00            14.0  1.847673
#         1353533        4.90             3.2  1.789419
#         1353522      112.00            78.0  2.105169
#         1353532      135.00           120.0  1.946836
#         1353531        8.80            18.0  1.741571
#         1353529       20.00            39.0  1.608707
#         1353528       31.00            50.0  1.669041
#         1353530       21.00            19.0  1.897120
#         1353526      316.00           138.0  2.250910
#         1353525       53.00           120.0  1.846091
#         1353524       72.00           106.0  1.794517
#         1353523        8.40            10.0  2.058741
#         1360563       44.00            19.0  1.804510
#         1360562       18.00            13.0  1.752427
#         1360561        2.90             4.1  1.584356
#         1360560       10.00            10.0  1.788028
#         1360570       24.00            11.0  1.763677
#         1360559       33.00            22.0  1.731815
#         1360572       14.00            14.0  1.801415
#         1360571       17.00            17.0  1.798946
# 112147  1360869       17.00            29.0  1.547076
#         1360867       34.00            22.0  1.615877
#         1360868       50.00            19.0  1.342912
#         1360877       28.00             5.9  1.669723
#         1360876        3.50             8.5  1.331789
#         1360875       15.00             9.9  1.593941
#         1360874       88.00            17.0  1.958004
#         1360873        1.80             3.3  1.350985
#         1360872       34.00            17.0  1.697055
#         1360871       43.00            11.0  1.541640
#         1360870       11.00             6.4  1.441171

# %%
balphagore2.bet(balphagore2.df)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1281/1281 [01:59<00:00, 10.76it/s]

# %%
balphagore2.compute_profit()
# Out:
#   0%|                                                                                                                                                         | 7/9880 [00:00<10:19, 15.93it/s]/opt/pysetup/.venv/lib/python3.7/site-packages/numpy/core/numeric.py:2378: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return bool(asarray(a1 == a2).all())
#  11%|█████████████████                                                                                                                                     | 1120/9880 [00:14<01:43, 84.81it/s]
# 4 [5]
# 5 [5]
# 2 [5]
# 4 [4]
# 5 [4]
# 2 [4]
# 4 [1]
# 5 [1]
# 2 [1]
# 4 [3]
# 5 [3]
# 2 [3]
# 4 [7]
# 5 [7]
# 2 [7]
# 4 [8]
# 5 [8]
# 2 [8]
# 4 [6]
# 5 [6]
# 2 [6]
# 4 [2]
# 5 [2]
# 2 [2]
#  33%|██████████████████████████████████████████████████                                                                                                    | 3301/9880 [00:41<01:20, 81.97it/s]
# 6-4 [6, 3, 8]
# 6-3 [6, 3, 8]
# 6-1 [6, 3, 8]
# 4-3 [6, 3, 8]
# 4-1 [6, 3, 8]
# 3-1 [6, 3, 8]
# 4 [6]
# 6 [6]
# 3 [6]
# 6-4 [3, 8, 5]
# 6-3 [3, 8, 5]
# 6-1 [3, 8, 5]
# 4-3 [3, 8, 5]
# 4-1 [3, 8, 5]
# 3-1 [3, 8, 5]
# 4 [3]
# 6 [3]
# 3 [3]
# 6-4 [8, 5, 4]
# 6-3 [8, 5, 4]
# 6-1 [8, 5, 4]
# 4-3 [8, 5, 4]
# 4-1 [8, 5, 4]
# 3-1 [8, 5, 4]
# 4 [8]
# 6 [8]
# 3 [8]
# 6-4 [5, 4, 1]
# 6-3 [5, 4, 1]
# 6-1 [5, 4, 1]
# 4-3 [5, 4, 1]
# 4-1 [5, 4, 1]
# 3-1 [5, 4, 1]
# 4 [5]
# 6 [5]
# 3 [5]
# 6-4 [2, 10, 9]
# 6-3 [2, 10, 9]
# 6-1 [2, 10, 9]
# 4-3 [2, 10, 9]
# 4-1 [2, 10, 9]
# 3-1 [2, 10, 9]
# 4 [2]
# 6 [2]
# 3 [2]
# 6-4 [10, 9, 7]
# 6-3 [10, 9, 7]
# 6-1 [10, 9, 7]
# 4-3 [10, 9, 7]
# 4-1 [10, 9, 7]
# 3-1 [10, 9, 7]
# 4 [10]
# 6 [10]
# 3 [10]
# 6-4 [9, 7, 1]
# 6-3 [9, 7, 1]
# 6-1 [9, 7, 1]
# 4-3 [9, 7, 1]
# 4-1 [9, 7, 1]
# 3-1 [9, 7, 1]
# 4 [9]
# 6 [9]
# 3 [9]
# 6-4 [7, 1, 4]
# 6-3 [7, 1, 4]
# 6-1 [7, 1, 4]
# 4-3 [7, 1, 4]
# 4-1 [7, 1, 4]
# 3-1 [7, 1, 4]
# 4 [7]
# 6 [7]
# 3 [7]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9880/9880 [02:11<00:00, 75.29it/s]

# %%
b = balphagore2.bets

# %%
b.filter(regex='^top', axis=1).describe()
# Out:
#        top1_correct  top1_in_3_correct  top2_correct  top2_correct_disorder  \
# count   9880.000000        9880.000000   9880.000000            9880.000000
# mean       0.100810           0.294028      0.014575               0.026923
# std        0.301092           0.455628      0.119850               0.161867
# min        0.000000           0.000000      0.000000               0.000000
# 25%        0.000000           0.000000      0.000000               0.000000
# 50%        0.000000           0.000000      0.000000               0.000000
# 75%        0.000000           1.000000      0.000000               0.000000
# max        1.000000           1.000000      1.000000               1.000000
#
#        top3_correct  top3_correct_disorder  top4_correct  \
# count   9880.000000            9880.000000   9880.000000
# mean       0.002632               0.014980      0.000607
# std        0.051234               0.121478      0.024637
# min        0.000000               0.000000      0.000000
# 25%        0.000000               0.000000      0.000000
# 50%        0.000000               0.000000      0.000000
# 75%        0.000000               0.000000      0.000000
# max        1.000000               1.000000      1.000000
#
#        top4_correct_disorder  top2_in_4_correct
# count            9880.000000        9880.000000
# mean                0.012652           0.137854
# std                 0.111772           0.344764
# min                 0.000000           0.000000
# 25%                 0.000000           0.000000
# 50%                 0.000000           0.000000
# 75%                 0.000000           0.000000
# max                 1.000000           1.000000

# %%
b.filter(regex='^profit_', axis=1).describe()

# %%
subcat = 'AUTOSTART'
col = 'profit_top3_correct_disorder'
strat = 7

b = balphagore2.bets
b = b[(b['sub_category']==subcat) & (b['final_odds'] < 30) & ((b['strategy']==strat+1)) & (b['declared_player_count']<14)].copy()
b.reset_index(inplace=True, drop=True)
b[col].cumsum().plot()
b[profit_cols].mean()
# Out:
# profit_win                     -0.652778
# profit_placed                  -0.424306
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -0.833333
# profit_top3_correct            -0.152778
# profit_top3_correct_disorder   -0.833333
# profit_top4_correct             0.000000
# profit_top4_correct_disorder    0.000000
# profit_top2_in_4_correct        0.036111
# dtype: float64

# %%
subcat = 'HANDICAP'
col = 'profit_win'
strat = 7

b = balphagore2.bets
b = b[(b['sub_category']==subcat) & (b['b_odds_1'] > 30) & ((b['strategy']==strat+1))].copy()
b.reset_index(inplace=True, drop=True)
b[col].cumsum().plot()
b[profit_cols].mean()
# Out:
# profit_win                      2.692308
# profit_placed                   0.200000
# profit_top2_correct             0.000000
# profit_top2_correct_disorder   -1.000000
# profit_top3_correct             0.000000
# profit_top3_correct_disorder   -0.846154
# profit_top4_correct            -0.153846
# profit_top4_correct_disorder   -0.384615
# profit_top2_in_4_correct       -0.615385
# dtype: float64

# %%
(1/30) * 14
# Out:
# 0.4666666666666667
