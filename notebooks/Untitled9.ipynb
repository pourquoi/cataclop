# %%
from cataclop.pmu import parser
from cataclop.pmu.settings import SCRAP_DIR

# %%
p = parser.Parser(SCRAP_DIR)

# %%
from cataclop.core.models import *

qs = Player.objects.filter(position=1, winner_dividend__isnull=True, race__start_at__lt="2016-01-01").prefetch_related('race')

# %%
print(len(qs))
# Out:
# 6139

# %%
p.parseMissingDividend()
# Out:
# 2015-01-31
# R1C1
# R1C2
# R1C3
# R1C4
# R1C5
# R1C6
# R1C7
# R1C8
# R1C9
# R2C1
# R2C2
# R2C3
# R2C4
# R2C5
# R2C6
# R3C1
# 'nombrePlacesSecond'
# R3C2
# R3C3
# R3C4
# 'nombrePlacesSecond'
# R3C5
# R3C6
# R3C7
# R3C8
# R4C1
# R4C2
# R4C3
# R4C4
# R4C5
# R4C6
# R4C7
# R4C8
# R5C1
# R5C2
# 'nombrePlacesSecond'
# 'nombrePlacesSecond'
# R5C3
# R5C4
# R5C5
# R5C6
# R5C7
# R6C6
# 'nombrePlacesSecond'
# R6C7
# R6C8
# 2015-02-01
# R1C1
# R1C2
# R1C3
# R1C4
# R1C5
# R1C6
# R1C7
# R1C8
# R1C9
# R2C1
# R2C2
# R2C3
# R2C4
# R2C5
# R2C6
# R2C7
# R2C8
# R2C9
# R3C1
# R3C2
# R3C3
# R3C4
# R3C5
# R3C6
# R3C7
# 'nombrePlacesSecond'
# R3C8
# R4C1
# R4C2
# R4C3
# R4C4
# R4C5
# R4C6
# 'nombrePlacesSecond'
# R4C7
# R5C1
# R5C2
# R5C3
# R5C4
# R5C5
# R5C6
# R5C7
# 2015-02-02
# R1C1
# R1C2
# R1C3
# R1C4
# R1C5
# R1C6
# R1C7
# R1C8
# R2C1
# R2C2
# R2C3
# R2C4
# R2C5
# R2C6
# R2C7
# R2C8
# R2C9
# R3C1
# R3C2
# R3C3
# 'nombrePlacesSecond'
# R3C4
# R3C5
# R3C6
# R3C7
# R4C1
# R4C2
# R4C3
# R4C4
# R4C5
# R4C6
# ...
